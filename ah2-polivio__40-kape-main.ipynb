# %% [markdown]
# # **AH2-POLIVIO - 40 - KAPE - MAIN**

# %% [markdown]
# ## **FUNCTIONS, VARS, INIT**

# %%
# Define your notebook full file path here to be able to automatically store runtime configuration settings in this notebook
thisnb="/mnt/analysis/dev/testing_system/test_notebooks/ah2-polivio__40-kape-main.ipynb"

# Set casename here. This notebook must be renamed with that name.
# %run ah2-polivio__00_imports_case_variables.ipynb
# Out:
# <style>
# table {float:left}
# </style>

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ---

# %% [raw]
# # TO BE COPIED TO OTHER NOTEBOOKS FOR CODE DEBUGGING
#
# # importlib.reload(d4pl)
# importlib.reload(d4kp)
# importlib.reload(d4com)
# importlib.reload(d4gui)
# # importlib.reload(d4evtx)

# %% [markdown]
# ## **READ KAPE FILES**

# %% [markdown]
# ### **laptop-cdrive**

# %%
# Enter computer name here (i.e. evidence file prefix, e.g. compname = "dsk1723")
compname = 'ah2-policy_violation_case'
hostname = 'ah2-policy_violation_case'

# %% [markdown]
# #### **PATH DEFINITIONS**

# %% [markdown]
# ##### **FOREST**

# %% [markdown]
# **comp**<br>
# Use this configuration if you have a single computer, and its kape evidence is under the comp folder

# %%
compod  = caseod+'/f4n6/comps/'+compname
kaped = compod+'/kape'

# %%
kaped
# Out:
# '/mnt/analysis/cases//ah2-polivio/f4n6/comps/ah2-policy_violation_case/kape'

# %% [markdown]
# #### **READ DATA**

# %% [raw]
# # TO BE COPIED TO OTHER NOTEBOOKS FOR CODE DEBUGGING
#
# # importlib.reload(d4pl)
# importlib.reload(d4kp)
# importlib.reload(d4com)
# importlib.reload(d4gui)
# # importlib.reload(d4evtx)

# %%
read_data_gui(tool="kape", rootpath=kaped, folder_parsing_mode="single_host_with_categories", notebook_file=thisnb, use_pickle=False, hostname=hostname, path_prefix="G__exercises_kape_output-jg", pluginisdfname=True)
# Out:
# - Searching notebook for saved input file / folder (ah2-policy_violation_case_kaped)
#   + Found: /mnt/analysis/cases/ah2-polivio/f4n6/comps/ah2-policy_violation_case/kape
#
# - Reading file(s):
#   + Reading csv file 20201102233837_AutomaticDestinations.csv                                                                       into dataframe ->  FileFolderAccess-AutomaticDestinations
#   + Reading csv file G__0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT.csv                                                           into dataframe ->  FileFolderAccess-G__0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
#   + Reading csv file G__0-cases_ah2-polivio_F_users_Hunter_AppData_Local_Microsoft_Windows_UsrClass.dat.csv                         into dataframe ->  FileFolderAccess-G__0-cases_ah2-polivio_F_users_Hunter_AppData_Local_Microsoft_Windows_UsrClass.dat
#   + Reading csv file 20201102233837_LECmd_Output.csv                                                                                into dataframe ->  FileFolderAccess-LECmd
#   + Reading csv file 20201102233837_CustomDestinations.csv                                                                          into dataframe ->  FileFolderAccess-CustomDestinations
#   + Reading csv file 20201102233832_EvtxECmd_Output.csv                                                                             into dataframe ->  EventLogs-EvtxECmd
#   + Reading csv file 20201102233826_MFTECmd_$J_Output.csv                                                                           into dataframe ->  FileSystem-MFTECmd_$J
#   + Reading csv file 20201102233807_MFTECmd_$Boot_Output.csv                                                                        into dataframe ->  FileSystem-MFTECmd_$Boot
#   + Reading csv file 20201102233820_MFTECmd_$MFT_Output.csv                                                                         into dataframe ->  FileSystem-MFTECmd_$MFT
#   + Reading csv file 20201102233831_MFTECmd_$SDS_Output.csv                                                                         into dataframe ->  FileSystem-MFTECmd_$SDS
#   + Reading csv file 20201102233839_PECmd_Output_Timeline.csv                                                                       into dataframe ->  ProgramExecution-PECmd_Output_Timeline
#   + Reading csv file 20201102233804_Amcache_ProgramEntries.csv                                                                      into dataframe ->  ProgramExecution-Amcache_ProgramEntries
#   + Reading csv file 20201102233804_Amcache_AssociatedFileEntries.csv                                                               into dataframe ->  ProgramExecution-Amcache_AssociatedFileEntries
#   + Reading csv file 20201102233806_Windows81_Windows2012R2_SYSTEM_AppCompatCache.csv                                               into dataframe ->  ProgramExecution-Windows81_Windows2012R2_SYSTEM_AppCompatCache
#   + Reading csv file 20201102233839_PECmd_Output.csv                                                                                into dataframe ->  ProgramExecution-PECmd
#   + Reading csv file 20201102233804_Amcache_UnassociatedFileEntries.csv                                                             into dataframe ->  ProgramExecution-Amcache_UnassociatedFileEntries
#   + Reading csv file 20201102233841_KnownNetworks_G_0-cases_ah2-polivio_F_Windows_system32_config_SOFTWARE.csv                      into dataframe ->  Registry-KnownNetworks_G_0-cases_ah2-polivio_F_Windows_system32_config_SOFTWARE
#   + Reading csv file 20201102233841_CIDSizeMRU_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT.csv                                  into dataframe ->  Registry-CIDSizeMRU_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
#   + Reading csv file 20201102233841_FirstFolder_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT.csv                                 into dataframe ->  Registry-FirstFolder_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
#   + Reading csv file 20201102233841_RECmd_Batch_RECmd_Batch_MC_Output.csv                                                           into dataframe ->  Registry-RECmd_Batch_RECmd_Batch_MC
#   + Reading csv file 20201102233841_OpenSavePidlMRU_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT.csv                             into dataframe ->  Registry-OpenSavePidlMRU_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
#   + Reading csv file 20201102233841_RecentDocs_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT.csv                                  into dataframe ->  Registry-RecentDocs_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
#   + Reading csv file 20201102233841_MountedDevices_G_0-cases_ah2-polivio_F_Windows_system32_config_SYSTEM.csv                       into dataframe ->  Registry-MountedDevices_G_0-cases_ah2-polivio_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201102233841_TimeZoneInfo_G_0-cases_ah2-polivio_F_Windows_system32_config_SYSTEM.csv                         into dataframe ->  Registry-TimeZoneInfo_G_0-cases_ah2-polivio_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201102233841_UserAccounts_G_0-cases_ah2-polivio_F_Windows_system32_config_SAM.csv                            into dataframe ->  Registry-UserAccounts_G_0-cases_ah2-polivio_F_Windows_system32_config_SAM
#   + Reading csv file 20201102233841_LastVisitedPidlMRU_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT.csv                          into dataframe ->  Registry-LastVisitedPidlMRU_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
#   + Reading csv file 20201102233841_FileExts_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT.csv                                    into dataframe ->  Registry-FileExts_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
#   + Reading csv file 20201102233841_Services_G_0-cases_ah2-polivio_F_Windows_system32_config_SYSTEM.csv                             into dataframe ->  Registry-Services_G_0-cases_ah2-polivio_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201102233841_UserAssist_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT.csv                                  into dataframe ->  Registry-UserAssist_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
#
#
# NOTE: Now you can use the syntax <yourvar>['Category'] to access your dataframe
#
#
# - Reading Done.
#
# - Recover the object read by executing:  myvar = d4.out (e.g. mydf = d4.out)

# %%
# Automatically created - DO NOT EDIT OR REMOVE unless you want to change the file to read (in that case, remove this cell)
# 2021-03-30 19:28:30.754636
# ah2-policy_violation_case_kaped_f2read = "/mnt/analysis/cases/ah2-polivio/f4n6/comps/ah2-policy_violation_case/kape"

# %%
kpdfs = d4.out

# %% [markdown]
# ---

# %% [markdown]
# ## **ANALYSIS**

# %% [markdown]
# ### **GENERIC**

# %%
xdisplay()
# Out:
# #### Pandas options
# IntText(value=700, description='display.max_rows: ', style=DescriptionStyle(description_width='initial'))
# IntText(value=10, description='display.min_rows: ', style=DescriptionStyle(description_width='initial'))
# IntText(value=0, description='display.max_columns: ', style=DescriptionStyle(description_width='initial'))
# Dropdown(description='display.colheader_justify: ', index=1, options=('right', 'left'), style=DescriptionStyle…
# Checkbox(value=True, description='display.expand_frame_repr', indent=False, style=DescriptionStyle(description…

# %%
xmenu(kpdfs)
# Out:
# **DataFrame visualization menu:**
# Box(children=(Dropdown(description='Select DataFrame', layout=Layout(width='550px'), options=('Select DataFram…
# HBox(children=(Label(value='Selected dataframe: '),))
# HBox(children=(HTML(value="<div style='color: orange; font-weight: bold;'>Data Loading. Please Wait…</div>"),)…
# Output(layout=Layout(overflow='auto', width='99%'))
# Output(layout=Layout(overflow='auto', width='99%'))

# %%
dfs = d4.out

# %%
for category in kpdfs:
    print(category)
    kpdfs[category].simple()
    print('-------------------------------------------------------------------------------------------------------------')
# Out:
# FileFolderAccess-AutomaticDestinations
# **Statistics:**
# <br>No. Entries: 6
# **Constant Columns**
#    Column               \
# 0         D4_DataType_
# 1     D4_Orchestrator_
# 2             D4_Tool_
# 3           D4_Plugin_
# 4         D4_Hostname_
# 5       SourceAccessed
# 6      DestListVersion
# 7     InteractionCount
# 8            PinStatus
# 9         RelativePath
# 10    WorkingDirectory
# 11         HeaderFlags
# 12           DriveType
# 13  VolumeSerialNumber
# 14         VolumeLabel
# 15           LocalPath
# 16           Arguments
# 17               Notes
#
#    Value
# 0                                                                                    nan
# 1                                                                                   kape
# 2                                                                                   kape
# 3                                                 FileFolderAccess-AutomaticDestinations
# 4                                                              ah2-policy_violation_case
# 5                                                                    2020-11-02 23:38:37
# 6                                                                                      1
# 7                                                                                      0
# 8                                                                                  False
# 9                                                                                   <NA>
# 10                                                                                  <NA>
# 11  HasTargetIdList, HasLinkInfo, IsUnicode, DisableKnownFolderTracking, AllowLinkToLink
# 12                                                      Fixed storage media (Hard drive)
# 13                                                                              669B1B2A
# 14                                                                                  <NA>
# 15                                                                             C:\Users\
# 16                                                                                  <NA>
# 17                                                                                  <NA>
# <style  type="text/css" >
# #T_a9f02_row0_col0,#T_a9f02_row0_col1,#T_a9f02_row0_col2,#T_a9f02_row0_col3,#T_a9f02_row0_col4,#T_a9f02_row0_col5,#T_a9f02_row0_col6,#T_a9f02_row0_col7,#T_a9f02_row0_col8,#T_a9f02_row0_col9,#T_a9f02_row0_col10,#T_a9f02_row0_col11,#T_a9f02_row0_col12,#T_a9f02_row0_col13,#T_a9f02_row0_col14,#T_a9f02_row0_col15,#T_a9f02_row0_col16,#T_a9f02_row0_col17,#T_a9f02_row0_col18,#T_a9f02_row0_col19,#T_a9f02_row0_col20,#T_a9f02_row0_col21,#T_a9f02_row0_col22,#T_a9f02_row0_col23,#T_a9f02_row0_col24,#T_a9f02_row0_col25,#T_a9f02_row0_col26,#T_a9f02_row0_col27,#T_a9f02_row0_col28,#T_a9f02_row0_col29,#T_a9f02_row0_col30,#T_a9f02_row1_col0,#T_a9f02_row1_col1,#T_a9f02_row1_col2,#T_a9f02_row1_col3,#T_a9f02_row1_col4,#T_a9f02_row1_col5,#T_a9f02_row1_col6,#T_a9f02_row1_col7,#T_a9f02_row1_col8,#T_a9f02_row1_col9,#T_a9f02_row1_col10,#T_a9f02_row1_col11,#T_a9f02_row1_col12,#T_a9f02_row1_col13,#T_a9f02_row1_col14,#T_a9f02_row1_col15,#T_a9f02_row1_col16,#T_a9f02_row1_col17,#T_a9f02_row1_col18,#T_a9f02_row1_col19,#T_a9f02_row1_col20,#T_a9f02_row1_col21,#T_a9f02_row1_col22,#T_a9f02_row1_col23,#T_a9f02_row1_col24,#T_a9f02_row1_col25,#T_a9f02_row1_col26,#T_a9f02_row1_col27,#T_a9f02_row1_col28,#T_a9f02_row1_col29,#T_a9f02_row1_col30,#T_a9f02_row2_col0,#T_a9f02_row2_col1,#T_a9f02_row2_col2,#T_a9f02_row2_col3,#T_a9f02_row2_col4,#T_a9f02_row2_col5,#T_a9f02_row2_col6,#T_a9f02_row2_col7,#T_a9f02_row2_col8,#T_a9f02_row2_col9,#T_a9f02_row2_col10,#T_a9f02_row2_col11,#T_a9f02_row2_col12,#T_a9f02_row2_col13,#T_a9f02_row2_col14,#T_a9f02_row2_col15,#T_a9f02_row2_col16,#T_a9f02_row2_col17,#T_a9f02_row2_col18,#T_a9f02_row2_col19,#T_a9f02_row2_col20,#T_a9f02_row2_col21,#T_a9f02_row2_col22,#T_a9f02_row2_col23,#T_a9f02_row2_col24,#T_a9f02_row2_col25,#T_a9f02_row2_col26,#T_a9f02_row2_col27,#T_a9f02_row2_col28,#T_a9f02_row2_col29,#T_a9f02_row2_col30,#T_a9f02_row3_col0,#T_a9f02_row3_col1,#T_a9f02_row3_col2,#T_a9f02_row3_col3,#T_a9f02_row3_col4,#T_a9f02_row3_col5,#T_a9f02_row3_col6,#T_a9f02_row3_col7,#T_a9f02_row3_col8,#T_a9f02_row3_col9,#T_a9f02_row3_col10,#T_a9f02_row3_col11,#T_a9f02_row3_col12,#T_a9f02_row3_col13,#T_a9f02_row3_col14,#T_a9f02_row3_col15,#T_a9f02_row3_col16,#T_a9f02_row3_col17,#T_a9f02_row3_col18,#T_a9f02_row3_col19,#T_a9f02_row3_col20,#T_a9f02_row3_col21,#T_a9f02_row3_col22,#T_a9f02_row3_col23,#T_a9f02_row3_col24,#T_a9f02_row3_col25,#T_a9f02_row3_col26,#T_a9f02_row3_col27,#T_a9f02_row3_col28,#T_a9f02_row3_col29,#T_a9f02_row3_col30,#T_a9f02_row4_col0,#T_a9f02_row4_col1,#T_a9f02_row4_col2,#T_a9f02_row4_col3,#T_a9f02_row4_col4,#T_a9f02_row4_col5,#T_a9f02_row4_col6,#T_a9f02_row4_col7,#T_a9f02_row4_col8,#T_a9f02_row4_col9,#T_a9f02_row4_col10,#T_a9f02_row4_col11,#T_a9f02_row4_col12,#T_a9f02_row4_col13,#T_a9f02_row4_col14,#T_a9f02_row4_col15,#T_a9f02_row4_col16,#T_a9f02_row4_col17,#T_a9f02_row4_col18,#T_a9f02_row4_col19,#T_a9f02_row4_col20,#T_a9f02_row4_col21,#T_a9f02_row4_col22,#T_a9f02_row4_col23,#T_a9f02_row4_col24,#T_a9f02_row4_col25,#T_a9f02_row4_col26,#T_a9f02_row4_col27,#T_a9f02_row4_col28,#T_a9f02_row4_col29,#T_a9f02_row4_col30,#T_a9f02_row5_col0,#T_a9f02_row5_col1,#T_a9f02_row5_col2,#T_a9f02_row5_col3,#T_a9f02_row5_col4,#T_a9f02_row5_col5,#T_a9f02_row5_col6,#T_a9f02_row5_col7,#T_a9f02_row5_col8,#T_a9f02_row5_col9,#T_a9f02_row5_col10,#T_a9f02_row5_col11,#T_a9f02_row5_col12,#T_a9f02_row5_col13,#T_a9f02_row5_col14,#T_a9f02_row5_col15,#T_a9f02_row5_col16,#T_a9f02_row5_col17,#T_a9f02_row5_col18,#T_a9f02_row5_col19,#T_a9f02_row5_col20,#T_a9f02_row5_col21,#T_a9f02_row5_col22,#T_a9f02_row5_col23,#T_a9f02_row5_col24,#T_a9f02_row5_col25,#T_a9f02_row5_col26,#T_a9f02_row5_col27,#T_a9f02_row5_col28,#T_a9f02_row5_col29,#T_a9f02_row5_col30{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_a9f02_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >SourceFile</th>        <th class="col_heading level0 col2" >SourceCreated</th>        <th class="col_heading level0 col3" >SourceModified</th>        <th class="col_heading level0 col4" >AppId</th>        <th class="col_heading level0 col5" >AppIdDescription</th>        <th class="col_heading level0 col6" >LastUsedEntryNumber</th>        <th class="col_heading level0 col7" >MRU</th>        <th class="col_heading level0 col8" >EntryNumber</th>        <th class="col_heading level0 col9" >CreationTime</th>        <th class="col_heading level0 col10" >LastModified</th>        <th class="col_heading level0 col11" >Hostname</th>        <th class="col_heading level0 col12" >MacAddress</th>        <th class="col_heading level0 col13" >Path</th>        <th class="col_heading level0 col14" >FileBirthDroid</th>        <th class="col_heading level0 col15" >FileDroid</th>        <th class="col_heading level0 col16" >VolumeBirthDroid</th>        <th class="col_heading level0 col17" >VolumeDroid</th>        <th class="col_heading level0 col18" >TargetCreated</th>        <th class="col_heading level0 col19" >TargetModified</th>        <th class="col_heading level0 col20" >TargetAccessed</th>        <th class="col_heading level0 col21" >FileSize</th>        <th class="col_heading level0 col22" >FileAttributes</th>        <th class="col_heading level0 col23" >CommonPath</th>        <th class="col_heading level0 col24" >TargetIDAbsolutePath</th>        <th class="col_heading level0 col25" >TargetMFTEntryNumber</th>        <th class="col_heading level0 col26" >TargetMFTSequenceNumber</th>        <th class="col_heading level0 col27" >MachineID</th>        <th class="col_heading level0 col28" >MachineMACAddress</th>        <th class="col_heading level0 col29" >TrackerCreatedOn</th>        <th class="col_heading level0 col30" >ExtraBlocksPresent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a9f02_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a9f02_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_a9f02_row0_col1" class="data row0 col1" >G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations
# \47bb2136fda3f1ed.automaticDestinations-ms</td>
#                         <td id="T_a9f02_row0_col2" class="data row0 col2" >2016-06-21 12:27:37</td>
#                         <td id="T_a9f02_row0_col3" class="data row0 col3" >2016-06-21 12:27:38</td>
#                         <td id="T_a9f02_row0_col4" class="data row0 col4" >47bb2136fda3f1ed</td>
#                         <td id="T_a9f02_row0_col5" class="data row0 col5" >Unknown AppId</td>
#                         <td id="T_a9f02_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_a9f02_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_a9f02_row0_col8" class="data row0 col8" >1</td>
#                         <td id="T_a9f02_row0_col9" class="data row0 col9" >2016-06-21 11:40:41</td>
#                         <td id="T_a9f02_row0_col10" class="data row0 col10" >2016-06-21 12:27:37</td>
#                         <td id="T_a9f02_row0_col11" class="data row0 col11" >4orensics</td>
#                         <td id="T_a9f02_row0_col12" class="data row0 col12" >08:00:27:d2:69:d7</td>
#                         <td id="T_a9f02_row0_col13" class="data row0 col13" >C:\Users\Hunter\Documents\Welcome.docx</td>
#                         <td id="T_a9f02_row0_col14" class="data row0 col14" >fb7f9786-37a4-11e6-8254-080027d269d7</td>
#                         <td id="T_a9f02_row0_col15" class="data row0 col15" >fb7f9786-37a4-11e6-8254-080027d269d7</td>
#                         <td id="T_a9f02_row0_col16" class="data row0 col16" >6001b914-e7c7-4b42-8b78-781bc11ff193</td>
#                         <td id="T_a9f02_row0_col17" class="data row0 col17" >6001b914-e7c7-4b42-8b78-781bc11ff193</td>
#                         <td id="T_a9f02_row0_col18" class="data row0 col18" >2016-06-21 12:27:37</td>
# -------------------------------------------------------------------------------------------------------------
# FileFolderAccess-G__0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
# **Statistics:**
# <br>No. Entries: 3
# **Constant Columns**
#    Column                \
# 0          D4_DataType_
# 1      D4_Orchestrator_
# 2              D4_Tool_
# 3            D4_Plugin_
# 4          D4_Hostname_
# 5                  Slot
# 6           MRUPosition
# 7             CreatedOn
# 8            ModifiedOn
# 9            AccessedOn
# 10        LastWriteTime
# 11             MFTEntry
# 12    MFTSequenceNumber
# 13  ExtensionBlockCount
# 14       LastInteracted
# 15          HasExplored
# 16        Miscellaneous
#
#    Value
# 0                                                                 nan
# 1                                                                kape
# 2                                                                kape
# 3   FileFolderAccess-G__0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
# 4                                           ah2-policy_violation_case
# 5                                                                   0
# 6                                                                   0
# 7                                                                <NA>
# 8                                                                <NA>
# 9                                                                <NA>
# 10                                                2016-06-21 12:30:53
# 11                                                               <NA>
# 12                                                               <NA>
# 13                                                                  0
# 14                                                2016-06-21 12:30:53
# 15                                                              False
# 16                                                               <NA>
# <style  type="text/css" >
# #T_c6a86_row0_col0,#T_c6a86_row0_col1,#T_c6a86_row0_col2,#T_c6a86_row0_col3,#T_c6a86_row0_col4,#T_c6a86_row0_col5,#T_c6a86_row0_col6,#T_c6a86_row0_col7,#T_c6a86_row1_col0,#T_c6a86_row1_col1,#T_c6a86_row1_col2,#T_c6a86_row1_col3,#T_c6a86_row1_col4,#T_c6a86_row1_col5,#T_c6a86_row1_col6,#T_c6a86_row1_col7,#T_c6a86_row2_col0,#T_c6a86_row2_col1,#T_c6a86_row2_col2,#T_c6a86_row2_col3,#T_c6a86_row2_col4,#T_c6a86_row2_col5,#T_c6a86_row2_col6,#T_c6a86_row2_col7{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_c6a86_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >BagPath</th>        <th class="col_heading level0 col2" >NodeSlot</th>        <th class="col_heading level0 col3" >AbsolutePath</th>        <th class="col_heading level0 col4" >ShellType</th>        <th class="col_heading level0 col5" >Value</th>        <th class="col_heading level0 col6" >ChildBags</th>        <th class="col_heading level0 col7" >FirstInteracted</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6a86_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c6a86_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c6a86_row0_col1" class="data row0 col1" >BagMRU</td>
#                         <td id="T_c6a86_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_c6a86_row0_col3" class="data row0 col3" >Desktop\Computers and Devices</td>
#                         <td id="T_c6a86_row0_col4" class="data row0 col4" >Root folder: GUID</td>
#                         <td id="T_c6a86_row0_col5" class="data row0 col5" >Computers and Devices</td>
#                         <td id="T_c6a86_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_c6a86_row0_col7" class="data row0 col7" ><NA></td>
#             </tr>
#             <tr>
#                         <th id="T_c6a86_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c6a86_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c6a86_row1_col1" class="data row1 col1" >BagMRU\0</td>
#                         <td id="T_c6a86_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_c6a86_row1_col3" class="data row1 col3" >Desktop\Computers and Devices\vboxsrv</td>
#                         <td id="T_c6a86_row1_col4" class="data row1 col4" >Variable: Users property view</td>
#                         <td id="T_c6a86_row1_col5" class="data row1 col5" >vboxsrv</td>
#                         <td id="T_c6a86_row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_c6a86_row1_col7" class="data row1 col7" ><NA></td>
#             </tr>
#             <tr>
#                         <th id="T_c6a86_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c6a86_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c6a86_row2_col1" class="data row2 col1" >BagMRU\0\0</td>
#                         <td id="T_c6a86_row2_col2" class="data row2 col2" >2</td>
#                         <td id="T_c6a86_row2_col3" class="data row2 col3" >Desktop\Computers and Devices\vboxsrv\VBOXSVR\Desktop</td>
#                         <td id="T_c6a86_row2_col4" class="data row2 col4" >Network location</td>
#                         <td id="T_c6a86_row2_col5" class="data row2 col5" >\\VBOXSVR\Desktop</td>
#                         <td id="T_c6a86_row2_col6" class="data row2 col6" >0</td>
#                         <td id="T_c6a86_row2_col7" class="data row2 col7" >2016-06-21 12:30:53</td>
#             </tr>
#     </tbody></table>
# -------------------------------------------------------------------------------------------------------------
# FileFolderAccess-G__0-cases_ah2-polivio_F_users_Hunter_AppData_Local_Microsoft_Windows_UsrClass.dat
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 66
# **Constant Columns**
#   Column             \
# 0      D4_DataType_
# 1  D4_Orchestrator_
# 2          D4_Tool_
# 3        D4_Plugin_
# 4      D4_Hostname_
#
#   Value
# 0                                                                                                  nan
# 1                                                                                                 kape
# 2                                                                                                 kape
# 3  FileFolderAccess-G__0-cases_ah2-polivio_F_users_Hunter_AppData_Local_Microsoft_Windows_UsrClass.dat
# 4                                                                            ah2-policy_violation_case
#    BagPath      Slot  NodeSlot  MRUPosition  \
# 0       BagMRU  0      0        4
# 1       BagMRU  1      0        0
# 2       BagMRU  2      0        1
# 3       BagMRU  3      0        3
# 4       BagMRU  4      0        2
# ..         ...   ...       ...          ...
# 61  BagMRU\2\1  0     49        1
# 62  BagMRU\2\1  1     59        0
# 63  BagMRU\2\4  0     36        0
# 64    BagMRU\4  0     57        0
# 65  BagMRU\4\0  0     56        0
#
#    AbsolutePath                                                         \
# 0                                                Desktop\Control Panel
# 1                                                  Desktop\My Computer
# 2                        Desktop\Shared Documents Folder (Users Files)
# 3                                                Desktop\Recent Places
# 4                                        Desktop\Computers and Devices
# ..                                                                 ...
# 61          Desktop\Shared Documents Folder (Users Files)\Dropbox\Info
# 62       Desktop\Shared Documents Folder (Users Files)\Dropbox\Outlook
# 63  Desktop\Shared Documents Folder (Users Files)\Downloads\FTK-Imager
# 64                               Desktop\Computers and Devices\vboxsrv
# 65               Desktop\Computers and Devices\vboxsrv\VBOXSVR\Desktop
#
#    ShellType                      Value                                   \
# 0               Root folder: GUID                          Control Panel
# 1               Root folder: GUID                            My Computer
# 2               Root folder: GUID  Shared Documents Folder (Users Files)
# 3               Root folder: GUID                          Recent Places
# 4               Root folder: GUID                  Computers and Devices
# ..                            ...                                    ...
# 61                      Directory                                   Info
# 62                      Directory                                Outlook
# 63                      Directory                             FTK-Imager
# 64  Variable: Users property view                                vboxsrv
# 65               Network location                      \\VBOXSVR\Desktop
#
#     ChildBags CreatedOn            ModifiedOn           AccessedOn            \
# 0   4                         <NA>                 <NA>                 <NA>
# 1   6                         <NA>                 <NA>                 <NA>
# 2   5                         <NA>                 <NA>                 <NA>
# 3   0                         <NA>                 <NA>                 <NA>
# 4   1                         <NA>                 <NA>                 <NA>
# ..        ...                  ...                  ...                  ...
# 61  0          2016-06-21 11:52:28  2016-06-21 11:52:28  2016-06-21 11:52:28
# 62  0          2016-06-21 13:14:26  2016-06-21 13:14:26  2016-06-21 13:14:26
# 63  0          2016-06-21 02:06:06  2016-06-21 02:06:10  2016-06-21 02:06:10
# 64  1                         <NA>                 <NA>                 <NA>
# 65  0                         <NA>                 <NA>                 <NA>
#
#    LastWriteTime        MFTEntry  MFTSequenceNumber  ExtensionBlockCount  \
# 0  2016-06-21 13:18:09    <NA>    <NA>               0
# 1  2016-06-21 13:18:09    <NA>    <NA>               0
# 2  2016-06-21 13:18:09    <NA>    <NA>               1
# 3  2016-06-21 13:18:09    <NA>    <NA>               0
# 4  2016-06-21 13:18:09    <NA>    <NA>               0
# ..                 ...       ...                ...                  ...
# 61 2016-06-21 13:14:29  110198       3               1
# 62 2016-06-21 13:14:29   87310      10               1
# 63 2016-06-21 02:06:13   23863       3               1
# 64 2016-06-21 12:30:50    <NA>    <NA>               0
# 65 2016-06-21 12:30:50    <NA>    <NA>               0
#
#    FirstInteracted      LastInteracted        HasExplored Miscellaneous
# 0                  <NA>                 <NA>  False                    <NA>
# 1                  <NA>  2016-06-21 13:18:09  False                    <NA>
# 2                  <NA>                 <NA>  False                    <NA>
# 3   2016-06-21 11:48:35                 <NA>  False                    <NA>
# 4                  <NA>                 <NA>  False                    <NA>
# ..                  ...                  ...          ...               ...
# 61  2016-06-21 12:02:18                 <NA>  False        NTFS file system
# 62  2016-06-21 13:14:29  2016-06-21 13:14:29  False        NTFS file system
# 63  2016-06-21 02:06:13  2016-06-21 02:06:13  False        NTFS file system
# 64                 <NA>  2016-06-21 12:30:50  False                    <NA>
# 65  2016-06-21 12:30:50  2016-06-21 12:30:50  False                    <NA>
#
# [66 rows x 19 columns]
# -------------------------------------------------------------------------------------------------------------
# FileFolderAccess-LECmd
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 40
# **Constant Columns**
#   Column            Value
# 0      D4_DataType_                        nan
# 1  D4_Orchestrator_                       kape
# 2          D4_Tool_                       kape
# 3        D4_Plugin_     FileFolderAccess-LECmd
# 4      D4_Hostname_  ah2-policy_violation_case
# 5    SourceAccessed        2020-11-02 23:38:37
# 6       VolumeLabel                       <NA>
#    SourceFile                                                                                                                                 \
# 0                                                                                  G:\0-cases\ah2-polivio\F\users\Hunter\Desktop\Dropbox.lnk
# 1                                                                             G:\0-cases\ah2-polivio\F\users\Hunter\Desktop\Google Drive.lnk
# 2                                                                        G:\0-cases\ah2-polivio\F\users\Hunter\Desktop\Nmap - Zenmap GUI.lnk
# 3                                                                   G:\0-cases\ah2-polivio\F\users\Hunter\Desktop\OLLYDBG.EXE - Shortcut.lnk
# 4                                                                      G:\0-cases\ah2-polivio\F\users\Hunter\Desktop\pscp.exe - Shortcut.lnk
# ..                                                                                                                                       ...
# 35                                                G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\Outlook.lnk
# 36                                           G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\Welcome.docx.lnk
# 37      G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Internet Explorer\Quick Launch\User
# Pinned\TaskBar\File Explorer.lnk
# 38      G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Internet Explorer\Quick Launch\User
# Pinned\TaskBar\Google Chrome.lnk
# 39  G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Internet Explorer\Quick Launch\User
# Pinned\TaskBar\Internet Explorer.lnk
#
#    SourceCreated       SourceModified      TargetCreated        \
# 0  2016-06-21 01:50:12 2016-06-21 01:50:12 2016-06-21 01:46:43
# 1  2016-06-21 01:54:21 2016-06-21 01:54:21 2016-06-21 01:54:20
# 2  2016-06-21 11:06:18 2016-06-21 11:06:18 2016-03-29 15:41:16
# 3  2016-06-21 11:08:05 2016-06-21 11:08:05 2016-06-21 11:07:12
# 4  2016-06-21 11:08:15 2016-06-21 11:08:15 2016-06-20 23:57:41
# ..                 ...                 ...                 ...
# 35 2016-06-21 13:15:00 2016-06-21 13:15:00 2016-06-21 13:14:25
# 36 2016-06-21 12:27:37 2016-06-21 12:27:37                 NaT
# 37 2016-06-21 08:37:57 2013-08-22 06:54:22                 NaT
# 38 2016-06-21 08:43:03 2016-06-21 08:43:03 2016-06-21 08:43:03
# 39 2016-06-21 08:37:57 2016-06-21 08:37:50 2014-03-18 10:14:20
#
#    TargetModified      TargetAccessed       FileSize  \
# 0  2016-05-31 18:34:50 2016-06-21 01:46:13  23972712
# 1  2016-06-21 01:54:21 2016-06-21 01:54:21         0
# 2  2016-03-29 15:41:16 2016-06-21 11:02:03    441344
# 3  2004-05-23 08:10:00 2016-06-21 11:07:12   1117696
# 4  2016-06-20 23:57:42 2016-06-20 23:57:41    359336
# ..                 ...                 ...       ...
# 35 2016-06-21 13:14:59 2016-06-21 13:14:59         0
# 36                 NaT                 NaT         0
# 37                 NaT                 NaT         0
# 38 2016-06-15 08:27:03 2016-06-21 08:43:03   1122456
# 39 2014-03-18 10:14:20 2014-03-18 10:14:20    809648
#
#    RelativePath                                                              \
# 0                   ..\..\..\Program Files (x86)\Dropbox\Client\Dropbox.exe
# 1                                                           ..\Google Drive
# 2                              ..\..\..\Program Files (x86)\Nmap\zenmap.exe
# 3                                          ..\Downloads\Ollydbg\OLLYDBG.EXE
# 4                                                     ..\Downloads\pscp.exe
# ..                                                                      ...
# 35                                           ..\..\..\..\..\Dropbox\Outlook
# 36                                    ..\..\..\..\..\Documents\Welcome.docx
# 37                                                                     <NA>
# 38  ..\..\..\..\..\Program Files (x86)\Google\Chrome\Application\chrome.exe
# 39     ..\..\..\..\..\..\..\..\Program Files\Internet Explorer\iexplore.exe
#
#    WorkingDirectory                                   \
# 0              C:\Program Files (x86)\Dropbox\Client
# 1                                               <NA>
# 2                        C:\Program Files (x86)\Nmap
# 3                  C:\Users\Hunter\Downloads\Ollydbg
# 4                          C:\Users\Hunter\Downloads
# ..                                               ...
# 35                                              <NA>
# 36                         C:\Users\Hunter\Documents
# 37                                              <NA>
# 38  C:\Program Files (x86)\Google\Chrome\Application
# 39                             %HOMEDRIVE%%HOMEPATH%
#
#    FileAttributes                                  \
# 0                            FileAttributeArchive
# 1   FileAttributeReadonly, FileAttributeDirectory
# 2                            FileAttributeArchive
# 3                            FileAttributeArchive
# 4                            FileAttributeArchive
# ..                                            ...
# 35   FileAttributeDirectory, FileAttributeArchive
# 36                                              0
# 37                                              0
# 38                           FileAttributeArchive
# 39                           FileAttributeArchive
#
#    HeaderFlags                                                                                                     \
# 0                  HasTargetIdList, HasLinkInfo, HasName, HasRelativePath, HasWorkingDir, HasArguments, IsUnicode
# 1                  HasTargetIdList, HasLinkInfo, HasName, HasRelativePath, HasIconLocation, IsUnicode, HasExpIcon
# 2                                         HasTargetIdList, HasLinkInfo, HasRelativePath, HasWorkingDir, IsUnicode
# 3                   HasTargetIdList, HasLinkInfo, HasRelativePath, HasWorkingDir, IsUnicode, EnableTargetMetadata
# 4                   HasTargetIdList, HasLinkInfo, HasRelativePath, HasWorkingDir, IsUnicode, EnableTargetMetadata
# ..                                                                                                            ...
# 35                           HasTargetIdList, HasLinkInfo, HasRelativePath, IsUnicode, DisableKnownFolderTracking
# 36            HasTargetIdList, HasLinkInfo, HasRelativePath, HasWorkingDir, IsUnicode, DisableKnownFolderTracking
# 37                                          HasTargetIdList, HasName, HasIconLocation, IsUnicode, ForceNoLinkInfo
# 38  HasTargetIdList, HasLinkInfo, HasName, HasRelativePath, HasWorkingDir, HasIconLocation, IsUnicode,
# HasExpIcon
# 39                               HasTargetIdList, HasLinkInfo, HasName, HasRelativePath, HasWorkingDir, IsUnicode
#
#    DriveType                         VolumeSerialNumber  \
# 0   Fixed storage media (Hard drive)  669B1B2A
# 1   Fixed storage media (Hard drive)  669B1B2A
# 2   Fixed storage media (Hard drive)  669B1B2A
# 3   Fixed storage media (Hard drive)  669B1B2A
# 4   Fixed storage media (Hard drive)  669B1B2A
# ..                               ...                ...
# 35  Fixed storage media (Hard drive)  669B1B2A
# 36  Fixed storage media (Hard drive)  669B1B2A
# 37                            (None)      <NA>
# 38  Fixed storage media (Hard drive)  669B1B2A
# 39  Fixed storage media (Hard drive)  669B1B2A
#
#    LocalPath                                                     \
# 0             C:\Program Files (x86)\Dropbox\Client\Dropbox.exe
# 1                                                     C:\Users\
# 2                        C:\Program Files (x86)\Nmap\zenmap.exe
# 3                                                     C:\Users\
# 4                                                     C:\Users\
# ..                                                          ...
# 35                                                    C:\Users\
# 36                                                    C:\Users\
# 37                                                         <NA>
# 38  C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# 39              C:\Program Files\Internet Explorer\iexplore.exe
#
#    NetworkPath        CommonPath                            Arguments  \
# 0                <NA>                                  <NA>  /home
# 1   \\4ORENSICS\Users                   Hunter\Google Drive   <NA>
# 2                <NA>                                  <NA>   <NA>
# 3   \\4ORENSICS\Users  Hunter\Downloads\Ollydbg\OLLYDBG.EXE   <NA>
# 4   \\4ORENSICS\Users             Hunter\Downloads\pscp.exe   <NA>
# ..                ...                                   ...       ...
# 35  \\4ORENSICS\Users                Hunter\Dropbox\Outlook   <NA>
# 36  \\4ORENSICS\Users         Hunter\Documents\Welcome.docx   <NA>
# 37               <NA>                                  <NA>   <NA>
# 38               <NA>                                  <NA>   <NA>
# 39               <NA>                                  <NA>   <NA>
#
#    TargetIDAbsolutePath                                                           \
# 0                  My Computer\C:\Program Files (x86)\Dropbox\Client\Dropbox.exe
# 1                             Shared Documents Folder (Users Files)\Google Drive
# 2                             My Computer\C:\Program Files (x86)\Nmap\zenmap.exe
# 3                                      My Computer\Downloads\Ollydbg\OLLYDBG.EXE
# 4                                                 My Computer\Downloads\pscp.exe
# ..                                                                           ...
# 35                         Shared Documents Folder (Users Files)\Dropbox\Outlook
# 36  User Libraries\Documents\Local Disk (C:)\Users\Hunter\Documents\Welcome.docx
# 37                           Unmapped GUID: 52205fd8-5dfb-447d-801a-d0b52f2e83e1
# 38       My Computer\C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# 39                   My Computer\C:\Program Files\Internet Explorer\iexplore.exe
#
#    TargetMFTEntryNumber TargetMFTSequenceNumber MachineID  MachineMACAddress   \
# 0    0x5DEA               0x2                    4orensics  08:00:27:d2:69:d7
# 1     0x5AB               0x3                    4orensics  08:00:27:d2:69:d7
# 2   0x15DC8               0x5                    4orensics  08:00:27:d2:69:d7
# 3   0x15F4D               0x2                    4orensics  08:00:27:d2:69:d7
# 4   0x17070               0x3                    4orensics  08:00:27:d2:69:d7
# ..                  ...                     ...        ...                ...
# 35  0x1550E               0xA                    4orensics  08:00:27:d2:69:d7
# 36      0x0              <NA>                         <NA>               <NA>
# 37     <NA>              <NA>                         <NA>               <NA>
# 38  0x1488E               0x1                    4orensics  08:00:27:d2:69:d7
# 39   0x465B               0x1                    4orensics  00:15:5d:8d:a0:f0
#
#    MACVendor          TrackerCreatedOn     \
# 0   PCS SYSTEMTECHNIK 2016-06-21 11:40:41
# 1   PCS SYSTEMTECHNIK 2016-06-21 11:40:41
# 2   PCS SYSTEMTECHNIK 2016-06-21 11:40:41
# 3   PCS SYSTEMTECHNIK 2016-06-21 11:40:41
# 4   PCS SYSTEMTECHNIK 2016-06-21 11:40:41
# ..                ...                 ...
# 35  PCS SYSTEMTECHNIK 2016-06-21 11:40:41
# 36               <NA>                 NaT
# 37               <NA>                 NaT
# 38  PCS SYSTEMTECHNIK 2016-06-21 08:19:10
# 39          MICROSOFT 2014-03-18 10:19:11
#
#    ExtraBlocksPresent
# 0                             SpecialFolderDataBlock, KnownFolderDataBlock, PropertyStoreDataBlock, TrackerDataBaseBlock
# 1                           IconEnvironmentDataBlock, KnownFolderDataBlock, PropertyStoreDataBlock, TrackerDataBaseBlock
# 2                             SpecialFolderDataBlock, KnownFolderDataBlock, PropertyStoreDataBlock, TrackerDataBaseBlock
# 3                             SpecialFolderDataBlock, KnownFolderDataBlock, PropertyStoreDataBlock, TrackerDataBaseBlock
# 4                             SpecialFolderDataBlock, KnownFolderDataBlock, PropertyStoreDataBlock, TrackerDataBaseBlock
# ..                                                                                                                   ...
# 35                                                                          PropertyStoreDataBlock, TrackerDataBaseBlock
# 36                                                                                                PropertyStoreDataBlock
# 37                                                                                                PropertyStoreDataBlock
# 38  IconEnvironmentDataBlock, SpecialFolderDataBlock, KnownFolderDataBlock, PropertyStoreDataBlock,
# TrackerDataBaseBlock
# 39                            SpecialFolderDataBlock, KnownFolderDataBlock, PropertyStoreDataBlock, TrackerDataBaseBlock
#
# [40 rows x 25 columns]
# -------------------------------------------------------------------------------------------------------------
# FileFolderAccess-CustomDestinations
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 31
# **Constant Columns**
#   Column            Value
# 0      D4_DataType_                                  nan
# 1  D4_Orchestrator_                                 kape
# 2          D4_Tool_                                 kape
# 3        D4_Plugin_  FileFolderAccess-CustomDestinations
# 4      D4_Hostname_            ah2-policy_violation_case
# 5    SourceAccessed                  2020-11-02 23:38:37
# 6      RelativePath                                 <NA>
# 7  WorkingDirectory                                 <NA>
# 8       VolumeLabel                                 <NA>
#    SourceFile                                                                                                                                  \
# 0   G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\28
# c8b86deab549a1.customDestinations-ms
# 1   G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\28
# c8b86deab549a1.customDestinations-ms
# 2   G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\28
# c8b86deab549a1.customDestinations-ms
# 3   G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\5d
# 696d521de238c3.customDestinations-ms
# 4   G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\5d
# 696d521de238c3.customDestinations-ms
# ..                                                                                                                                        ...
# 26  G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\cc
# c0fa1b9f86f7b3.customDestinations-ms
# 27  G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\cc
# c0fa1b9f86f7b3.customDestinations-ms
# 28  G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\cc
# c0fa1b9f86f7b3.customDestinations-ms
# 29  G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\cc
# c0fa1b9f86f7b3.customDestinations-ms
# 30  G:\0-cases\ah2-polivio\F\users\Hunter\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\cc
# c0fa1b9f86f7b3.customDestinations-ms
#
#    SourceCreated       SourceModified      AppId              \
# 0  2016-06-21 08:43:55 2016-06-21 12:01:46  28c8b86deab549a1
# 1  2016-06-21 08:43:55 2016-06-21 12:01:46  28c8b86deab549a1
# 2  2016-06-21 08:43:55 2016-06-21 12:01:46  28c8b86deab549a1
# 3  2016-06-21 08:43:23 2016-06-21 13:01:53  5d696d521de238c3
# 4  2016-06-21 08:43:23 2016-06-21 13:01:53  5d696d521de238c3
# ..                 ...                 ...               ...
# 26 2016-06-21 11:43:17 2016-06-21 12:28:08  ccc0fa1b9f86f7b3
# 27 2016-06-21 11:43:17 2016-06-21 12:28:08  ccc0fa1b9f86f7b3
# 28 2016-06-21 11:43:17 2016-06-21 12:28:08  ccc0fa1b9f86f7b3
# 29 2016-06-21 11:43:17 2016-06-21 12:28:08  ccc0fa1b9f86f7b3
# 30 2016-06-21 11:43:17 2016-06-21 12:28:08  ccc0fa1b9f86f7b3
#
#    AppIdDescription                                                         \
# 0                                     Internet Explorer 8.0.7600.16385 / 9
# 1                                     Internet Explorer 8.0.7600.16385 / 9
# 2                                     Internet Explorer 8.0.7600.16385 / 9
# 3   Google Chrome 9.0.597.84 / 12.0.742.100 / 13.0.785.215 / 48.0.2564.116
# 4   Google Chrome 9.0.597.84 / 12.0.742.100 / 13.0.785.215 / 48.0.2564.116
# ..                                                                     ...
# 26                                               CCleaner 5.15.5513 64-bit
# 27                                               CCleaner 5.15.5513 64-bit
# 28                                               CCleaner 5.15.5513 64-bit
# 29                                               CCleaner 5.15.5513 64-bit
# 30                                               CCleaner 5.15.5513 64-bit
#
#    EntryName     TargetCreated       TargetModified      TargetAccessed       \
# 0           <NA> 2014-03-18 10:14:20 2014-03-18 10:14:20 2014-03-18 10:14:20
# 1           <NA> 2014-03-18 10:14:20 2014-03-18 10:14:20 2014-03-18 10:14:20
# 2           <NA> 2014-03-18 10:14:20 2014-03-18 10:14:20 2014-03-18 10:14:20
# 3   Most visited 2016-06-21 08:43:03 2016-06-15 08:27:03 2016-06-21 08:43:03
# 4   Most visited 2016-06-21 08:43:03 2016-06-15 08:27:03 2016-06-21 08:43:03
# ..           ...                 ...                 ...                 ...
# 26          <NA>                 NaT                 NaT                 NaT
# 27          <NA> 2016-06-15 13:53:54 2016-06-15 13:53:54 2016-06-21 11:43:03
# 28          <NA> 2016-06-15 13:53:54 2016-06-15 13:53:54 2016-06-21 11:43:03
# 29          <NA> 2016-06-15 13:53:54 2016-06-15 13:53:54 2016-06-21 11:43:03
# 30          <NA> 2016-06-15 13:53:54 2016-06-15 13:53:54 2016-06-21 11:43:03
#
#     FileSize FileAttributes         \
# 0    809648   FileAttributeArchive
# 1    809648   FileAttributeArchive
# 2    809648   FileAttributeArchive
# 3   1122456   FileAttributeArchive
# 4   1122456   FileAttributeArchive
# ..       ...                   ...
# 26        0                      0
# 27  8810200   FileAttributeArchive
# 28  8810200   FileAttributeArchive
# 29  8810200   FileAttributeArchive
# 30  8810200   FileAttributeArchive
#
#    HeaderFlags                                                                                                                       \
# 0   HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
# 1   HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
# 2   HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
# 3   HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
# 4   HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
# ..                                                                                                                              ...
# 26                                                                           IsUnicode, DisableKnownFolderTracking, AllowLinkToLink
# 27  HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
# 28  HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
# 29  HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
# 30  HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon,
# DisableKnownFolderTracking, AllowLinkToLink
#
#    DriveType                         VolumeSerialNumber  \
# 0   Fixed storage media (Hard drive)  669B1B2A
# 1   Fixed storage media (Hard drive)  669B1B2A
# 2   Fixed storage media (Hard drive)  669B1B2A
# 3   Fixed storage media (Hard drive)  669B1B2A
# 4   Fixed storage media (Hard drive)  669B1B2A
# ..                               ...                ...
# 26                            (None)      <NA>
# 27  Fixed storage media (Hard drive)  669B1B2A
# 28  Fixed storage media (Hard drive)  669B1B2A
# 29  Fixed storage media (Hard drive)  669B1B2A
# 30  Fixed storage media (Hard drive)  669B1B2A
#
#    LocalPath                                                    CommonPath  \
# 0               C:\Program Files\Internet Explorer\iexplore.exe  <NA>
# 1               C:\Program Files\Internet Explorer\iexplore.exe  <NA>
# 2               C:\Program Files\Internet Explorer\iexplore.exe  <NA>
# 3   C:\Program Files (x86)\Google\Chrome\Application\chrome.exe  <NA>
# 4   C:\Program Files (x86)\Google\Chrome\Application\chrome.exe  <NA>
# ..                                                          ...        ...
# 26                                                         <NA>  <NA>
# 27                     C:\Program Files\CCleaner\CCleaner64.exe  <NA>
# 28                     C:\Program Files\CCleaner\CCleaner64.exe  <NA>
# 29                     C:\Program Files\CCleaner\CCleaner64.exe  <NA>
# 30                     C:\Program Files\CCleaner\CCleaner64.exe  <NA>
#
#    TargetIDAbsolutePath                                                      \
# 0               My Computer\C:\Program Files\Internet Explorer\iexplore.exe
# 1               My Computer\C:\Program Files\Internet Explorer\iexplore.exe
# 2               My Computer\C:\Program Files\Internet Explorer\iexplore.exe
# 3   My Computer\C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# 4   My Computer\C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# ..                                                                      ...
# 26                                                                     <NA>
# 27                     My Computer\C:\Program Files\CCleaner\CCleaner64.exe
# 28                     My Computer\C:\Program Files\CCleaner\CCleaner64.exe
# 29                     My Computer\C:\Program Files\CCleaner\CCleaner64.exe
# 30                     My Computer\C:\Program Files\CCleaner\CCleaner64.exe
#
#    TargetMFTEntryNumber TargetMFTSequenceNumber MachineID  MachineMACAddress   \
# 0    0x465B               0x1                    4orensics  00:15:5d:8d:a0:f0
# 1    0x465B               0x1                    4orensics  00:15:5d:8d:a0:f0
# 2    0x465B               0x1                    4orensics  00:15:5d:8d:a0:f0
# 3   0x1488E               0x1                    4orensics  08:00:27:d2:69:d7
# 4   0x1488E               0x1                    4orensics  08:00:27:d2:69:d7
# ..                  ...                     ...        ...                ...
# 26     <NA>              <NA>                         <NA>               <NA>
# 27  0x15A77               0xA                    4orensics  08:00:27:d2:69:d7
# 28  0x15A77               0xA                    4orensics  08:00:27:d2:69:d7
# 29  0x15A77               0xA                    4orensics  08:00:27:d2:69:d7
# 30  0x15A77               0xA                    4orensics  08:00:27:d2:69:d7
#
#    TrackerCreatedOn     \
# 0  2014-03-18 10:19:11
# 1  2014-03-18 10:19:11
# 2  2014-03-18 10:19:11
# 3  2016-06-21 08:19:10
# 4  2016-06-21 08:19:10
# ..                 ...
# 26                 NaT
# 27 2016-06-21 11:40:41
# 28 2016-06-21 11:40:41
# 29 2016-06-21 11:40:41
# 30 2016-06-21 11:40:41
#
#    ExtraBlocksPresent                                                       \
# 0   IconEnvironmentDataBlock, TrackerDataBaseBlock, PropertyStoreDataBlock
# ...
#                         <td id="T_14452_row1_col7" class="data row1 col7" >Type: Root folder: GUID, Value: My Computer      Type: Root folder: GUID, Value: Documents</td>
#             </tr>
#     </tbody></table>
# -------------------------------------------------------------------------------------------------------------
# Registry-FileExts_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 166
# **Constant Columns**
#   Column             \
# 0      D4_DataType_
# 1  D4_Orchestrator_
# 2          D4_Tool_
# 3        D4_Plugin_
# 4      D4_Hostname_
#
#   Value
# 0                                                                nan
# 1                                                               kape
# 2                                                               kape
# 3  Registry-FileExts_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
# 4                                          ah2-policy_violation_case
#     BatchKeyPath                                                                                                             \
# 0    CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# 1    CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# 2    CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# 3    CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# 4    CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# ..                                                                                                                      ...
# 161  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# 162  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# 163  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# 164  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\FileExts
# 165                                                                                                                    <NA>
#
#     BatchValueName Extension     OpensWithExecutables  \
# 0    Multiple                  .  <NA>
# 1    Multiple               .3g2  <NA>
# 2    Multiple               .3gp  <NA>
# 3    Multiple              .3gp2  <NA>
# 4    Multiple              .3gpp  <NA>
# ..             ...           ...                  ...
# 161  Multiple               .xps  <NA>
# 162  Multiple               .xsl  <NA>
# 163  Multiple               .zip  <NA>
# 164  Multiple               http  <NA>
# 165      <NA>       OpenWithList  <NA>
#
#     OpensWithProgramIDs              UserChoice
# 0                               <NA>          (UserChoice key not present)
# 1                WMP11.AssocFile.3G2                   WMP11.AssocFile.3G2
# 2                WMP11.AssocFile.3GP                   WMP11.AssocFile.3GP
# 3                WMP11.AssocFile.3G2                   WMP11.AssocFile.3G2
# 4                WMP11.AssocFile.3GP                   WMP11.AssocFile.3GP
# ..                               ...                                   ...
# 161           Windows.XPSReachViewer  AppX86746z2101ayy2ygv3g96e4eqdf8r99j
# 162                          xslfile          (UserChoice key not present)
# 163                 CompressedFolder          (UserChoice key not present)
# 164  URL:HyperText Transfer Protocol          (UserChoice key not present)
# 165                             <NA>          (UserChoice key not present)
#
# [166 rows x 6 columns]
# -------------------------------------------------------------------------------------------------------------
# Registry-Services_G_0-cases_ah2-polivio_F_Windows_system32_config_SYSTEM
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 495
# **Constant Columns**
#   Column             \
# 0      D4_DataType_
# 1  D4_Orchestrator_
# 2          D4_Tool_
# 3        D4_Plugin_
# 4      D4_Hostname_
# 5      BatchKeyPath
# 6    BatchValueName
#
#   Value
# 0                                                                               nan
# 1                                                                              kape
# 2                                                                              kape
# 3          Registry-Services_G_0-cases_ah2-polivio_F_Windows_system32_config_SYSTEM
# 4                                                         ah2-policy_violation_case
# 5  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\ControlSet001\Services
# 6                                                                              None
#     Name                                     \
# 0                             .NET CLR Data
# 1                       .NET CLR Networking
# 2               .NET CLR Networking 4.0.0.0
# 3             .NET Data Provider for Oracle
# 4          .NET Data Provider for SqlServer
# ..                                      ...
# 490                               WUDFWpdFs
# 491                                 WwanSvc
# 492                                 xmlprov
# 493  {8718928D-CBEB-45EA-A621-800A9249001D}
# 494  {8CB9FBF6-AE23-4E1C-AA0A-EE23CB4FE736}
#
#     Description                               \
# 0                                       <NA>
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# ..                                       ...
# 490                                     <NA>
# 491  @%SystemRoot%\System32\wwansvc.dll,-258
# 492                                     <NA>
# 493                                     <NA>
# 494                                     <NA>
#
#     DisplayName                              StartMode ServiceType         \
# 0                                       <NA>  Disabled            Adapter
# 1                                       <NA>  Disabled            Adapter
# 2                                       <NA>  Disabled            Adapter
# 3                                       <NA>  Disabled            Adapter
# 4                                       <NA>  Disabled            Adapter
# ..                                       ...       ...                ...
# 490                                     <NA>    Manual       KernelDriver
# 491  @%SystemRoot%\System32\wwansvc.dll,-257    Manual  Win32ShareProcess
# 492                                     <NA>  Disabled            Adapter
# 493                                     <NA>  Disabled            Adapter
# 494                                     <NA>  Disabled            Adapter
#
#     NameKeyLastWrite    ParametersKeyLastWrite       Group  \
# 0   2013-08-22 15:37:10                         <NA>  <NA>
# 1   2013-08-22 15:37:10                         <NA>  <NA>
# 2   2013-08-22 15:37:10                         <NA>  <NA>
# 3   2013-08-22 15:37:10                         <NA>  <NA>
# 4   2013-08-22 15:37:10                         <NA>  <NA>
# ..                  ...                          ...   ...
# 490 2016-06-21 01:53:16                         <NA>  <NA>
# 491 2013-08-22 15:37:11  2013-08-22 15:37:09.8281909   TDI
# 492 2013-08-22 15:37:10  2013-08-22 15:37:09.8125661  <NA>
# 493 2013-08-22 14:46:20  2013-08-22 14:46:19.2909621  <NA>
# 494 2016-06-21 08:15:21  2016-06-21 08:15:20.8497984  <NA>
#
#     ImagePath                                                   ServiceDLL  \
# 0                                                          <NA>  <NA>
# 1                                                          <NA>  <NA>
# 2                                                          <NA>  <NA>
# 3                                                          <NA>  <NA>
# 4                                                          <NA>  <NA>
# ..                                                          ...        ...
# 490                     \SystemRoot\system32\DRIVERS\WUDFRd.sys  <NA>
# 491  %SystemRoot%\system32\svchost.exe -k LocalServiceNoNetwork  <NA>
# 492                                                        <NA>  <NA>
# 493                                                        <NA>  <NA>
# 494                                                        <NA>  <NA>
#
#     RequiredPrivileges
# 0                                                               <NA>
# 1                                                               <NA>
# 2                                                               <NA>
# 3                                                               <NA>
# 4                                                               <NA>
# ..                                                               ...
# 490                                                             <NA>
# 491  SeChangeNotifyPrivilege SeImpersonatePrivilege SeAuditPrivilege
# 492                                                             <NA>
# 493                                                             <NA>
# 494                                                             <NA>
#
# [495 rows x 11 columns]
# -------------------------------------------------------------------------------------------------------------
# Registry-UserAssist_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 87
# **Constant Columns**
#   Column             \
# 0      D4_DataType_
# 1  D4_Orchestrator_
# 2          D4_Tool_
# 3        D4_Plugin_
# 4      D4_Hostname_
#
#   Value
# 0                                                                  nan
# 1                                                                 kape
# 2                                                                 kape
# 3  Registry-UserAssist_G_0-cases_ah2-polivio_F_users_Hunter_NTUSER.DAT
# 4                                            ah2-policy_violation_case
#    BatchKeyPath                                                                                                                                                            \
# 0   CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{BCB48336-4DDD-48FF-BB0B-D3190DACB3E2}\Count
# 1   CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{BCB48336-4DDD-48FF-BB0B-D3190DACB3E2}\Count
# 2   CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{BCB48336-4DDD-48FF-BB0B-D3190DACB3E2}\Count
# 3   CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{BCB48336-4DDD-48FF-BB0B-D3190DACB3E2}\Count
# 4   CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{BCB48336-4DDD-48FF-BB0B-D3190DACB3E2}\Count
# ..                                                                                                                                                                    ...
# 82  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{F4E57C4B-2036-45F0-A9AB-443BCFE33D9F}\Count
# 83  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{F4E57C4B-2036-45F0-A9AB-443BCFE33D9F}\Count
# 84  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{F4E57C4B-2036-45F0-A9AB-443BCFE33D9F}\Count
# 85  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{F4E57C4B-2036-45F0-A9AB-443BCFE33D9F}\Count
# 86  CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\
# Explorer\UserAssist\{F4E57C4B-2036-45F0-A9AB-443BCFE33D9F}\Count
#
#    BatchValueName                                                            \
# 0                                                     HRZR_PGYPHNPbhag:pgbe
# 1                                                      gkg_1422148366_ra-HF
# 2                                                           HRZR_PGYFRFFVBA
# 3                                                      gkg_3006226685_ra-HF
# 4                                                     fvgr_1951618997_ra-hf
# ..                                                                      ...
# 82                         P:\Hfref\Uhagre\Qrfxgbc\chggl.rkr - Fubegphg.yax
# 83                                P:\Hfref\Choyvp\Qrfxgbc\GrnzIvrjre 11.yax
# 84                            P:\Hfref\Uhagre\Qrfxgbc\Aznc - Mraznc THV.yax
# 85  {0139Q44R-6NSR-49S2-8690-3QNSPNR6SSO8}\Clguba 2.7\VQYR (Clguba THV).yax
# 86             {0139Q44R-6NSR-49S2-8690-3QNSPNR6SSO8}\PPyrnare\PPyrnare.yax
#
#    ProgramName                                          RunCounter  \
# 0                                UEME_CTLCUACount:ctor  0
# 1                                 txt_1422148366_en-US  1
# 2                                      UEME_CTLSESSION  6
# 3                                 txt_3006226685_en-US  1
# 4                                site_1951618997_en-us  1
# ..                                                 ...         ...
# 82    C:\Users\Hunter\Desktop\putty.exe - Shortcut.lnk  1
# 83           C:\Users\Public\Desktop\TeamViewer 11.lnk  1
# 84       C:\Users\Hunter\Desktop\Nmap - Zenmap GUI.lnk  1
# 85  {Common Programs}\Python 2.7\IDLE (Python GUI).lnk  1
# 86             {Common Programs}\CCleaner\CCleaner.lnk  1
#
#     FocusCount FocusTime         LastExecuted
# 0   0           0d, 0h, 00m, 00s                         <NA>
# 1   0           0d, 0h, 00m, 10s  2016-06-21 09:26:15.8060000
# 2   0           0d, 0h, 01m, 00s                         <NA>
# 3   0           0d, 0h, 00m, 10s  2016-06-21 09:26:43.2430000
# 4   0           0d, 0h, 00m, 10s  2016-06-21 09:26:50.0240000
# ..         ...               ...                          ...
# 82  0           0d, 0h, 00m, 00s  2016-06-21 11:55:37.3140000
# 83  0           0d, 0h, 00m, 00s  2016-06-21 12:00:43.2380000
# 84  0           0d, 0h, 00m, 00s  2016-06-21 12:08:13.7960000
# 85  0           0d, 0h, 00m, 00s  2016-06-21 12:26:17.3990000
# 86  0           0d, 0h, 00m, 00s  2016-06-21 12:28:08.0450000
#
# [87 rows x 7 columns]
# -------------------------------------------------------------------------------------------------------------
