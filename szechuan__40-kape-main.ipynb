# %% [markdown]
# # **SZECHUAN - 40 - KAPE - MAIN**

# %% [markdown]
# ## **FUNCTIONS, VARS, INIT**

# %%
# Define your notebook full file path here to be able to automatically store runtime configuration settings in this notebook
thisnb="/mnt/analysis/dev/testing_system/test_notebooks/szechuan__40-kape-main.ipynb"

# Set casename here. This notebook must be renamed with that name.
# %run szechuan__00_imports_case_variables.ipynb
# Out:
# <style>
# table {float:left}
# </style>

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ---

# %% [raw]
# # TO BE COPIED TO OTHER NOTEBOOKS FOR CODE DEBUGGING
#
# # importlib.reload(d4pl)
# importlib.reload(d4kp)
# importlib.reload(d4com)
# importlib.reload(d4gui)
# # importlib.reload(d4evtx)

# %% [markdown]
# ## **READ KAPE FILES**

# %% [markdown]
# ### **laptop-cdrive**

# %%
# Enter computer name here (i.e. evidence file prefix, e.g. compname = "dsk1723")
compname = '20200918_0347_cdrive-ft-p03'
hostname = '20200918_0347_cdrive-ft-p03'

# %% [markdown]
# #### **PATH DEFINITIONS**

# %% [markdown]
# ##### **FOREST**

# %% [markdown]
# **comp**<br>
# Use this configuration if you have a single computer, and its kape evidence is under the comp folder

# %%
compod  = caseod+'/f4n6/comps/'+compname
kaped = compod+'/kape'

# %%
kaped
# Out:
# '/mnt/analysis/cases/szechuan/f4n6/comps/20200918_0347_cdrive-ft-p03/kape'

# %% [markdown]
# #### **READ DATA**

# %% [raw]
# # TO BE COPIED TO OTHER NOTEBOOKS FOR CODE DEBUGGING
#
# # importlib.reload(d4pl)
# importlib.reload(d4kp)
# importlib.reload(d4com)
# importlib.reload(d4gui)
# # importlib.reload(d4evtx)

# %%
read_data_gui(tool="kape", rootpath=kaped, folder_parsing_mode="single_host_with_categories", notebook_file=thisnb, use_pickle=False, hostname=hostname, path_prefix="G__exercises_kape_output-jg", pluginisdfname=True)
# Out:
# - Searching notebook for saved input file / folder (20200918_0347_cdrive-ft-p03_kaped)
#   + Found: /mnt/analysis/cases/szechuan/f4n6/comps/20200918_0347_cdrive-ft-p03/kape
#
# - Reading file(s):
#   + Reading csv file 2020-11-16T033123_!SANS_Triage_copylog.csv                                                                     into dataframe ->  artifacts-2020-11-16T033123_!SANS_Triage_copylog
#   + Reading csv file 2020-11-16T033123_!SANS_Triage_skiplog.csv                                                                     into dataframe ->  artifacts-2020-11-16T033123_!SANS_Triage_skiplog
#   + Reading csv file 20201116033046_AutomaticDestinations.csv                                                                       into dataframe ->  output/csv/FileFolderAccess-AutomaticDestinations
#   + Reading csv file 20201116033046_CustomDestinations.csv                                                                          into dataframe ->  output/csv/FileFolderAccess-CustomDestinations
#   + Reading csv file G__szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                                                into dataframe ->  output/csv/FileFolderAccess-G__szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033046_LECmd_Output.csv                                                                                into dataframe ->  output/csv/FileFolderAccess-LECmd
#   + Reading csv file G__szechuan_kape_artifacts_F_Users_Administrator_AppData_Local_Microsoft_Windows_UsrClass.dat.csv              into dataframe ->  output/csv/FileFolderAccess-G__szechuan_kape_artifacts_F_Users_Administrator_AppData_Local_Microsoft_Windows_UsrClass.dat
#   + Reading csv file 20201116033005_Amcache_ProgramEntries.csv                                                                      into dataframe ->  output/csv/ProgramExecution-Amcache_ProgramEntries
#   + Reading csv file 20201116033005_Amcache_UnassociatedFileEntries.csv                                                             into dataframe ->  output/csv/ProgramExecution-Amcache_UnassociatedFileEntries
#   + Reading csv file 20201116033008_Windows81_Windows2012R2_SYSTEM_AppCompatCache.csv                                               into dataframe ->  output/csv/ProgramExecution-Windows81_Windows2012R2_SYSTEM_AppCompatCache
#   + Reading csv file 20201116033005_Amcache_AssociatedFileEntries.csv                                                               into dataframe ->  output/csv/ProgramExecution-Amcache_AssociatedFileEntries
#   + Reading csv file 20201116033047_RBCmd_Output.csv                                                                                into dataframe ->  output/csv/FileDeletion-RBCmd
#   + Reading csv file 20201116033009_EvtxECmd_Output.csv                                                                             into dataframe ->  output/csv/EventLogs-EvtxECmd
#   + Reading csv file 20201116033049_MountedDevices_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM.csv                   into dataframe ->  output/csv/Registry-MountedDevices_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201116033049_LastVisitedPidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv               into dataframe ->  output/csv/Registry-LastVisitedPidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033049_KnownNetworks_G_szechuan_kape_artifacts_F_Windows_system32_config_SOFTWARE.csv                  into dataframe ->  output/csv/Registry-KnownNetworks_G_szechuan_kape_artifacts_F_Windows_system32_config_SOFTWARE
#   + Reading csv file 20201116033049_TerminalServerClient_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv             into dataframe ->  output/csv/Registry-TerminalServerClient_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033049_RecentDocs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                       into dataframe ->  output/csv/Registry-RecentDocs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033049_RECmd_Batch_RECmd_Batch_MC_Output.csv                                                           into dataframe ->  output/csv/Registry-RECmd_Batch_RECmd_Batch_MC
#   + Reading csv file 20201116033049_OpenSavePidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                  into dataframe ->  output/csv/Registry-OpenSavePidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033049_Services_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM.csv                         into dataframe ->  output/csv/Registry-Services_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201116033049_CIDSizeMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                       into dataframe ->  output/csv/Registry-CIDSizeMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033049_TimeZoneInfo_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM.csv                     into dataframe ->  output/csv/Registry-TimeZoneInfo_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201116033049_TypedURLs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                        into dataframe ->  output/csv/Registry-TypedURLs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033049_FileExts_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                         into dataframe ->  output/csv/Registry-FileExts_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033049_UserAssist_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                       into dataframe ->  output/csv/Registry-UserAssist_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033206_Amcache_UnassociatedFileEntries.csv                                                             into dataframe ->  output/json/ProgramExecution-Amcache_UnassociatedFileEntries
#   + Reading csv file 20201116033206_Amcache_ProgramEntries.csv                                                                      into dataframe ->  output/json/ProgramExecution-Amcache_ProgramEntries
#   + Reading csv file 20201116033208_Windows81_Windows2012R2_SYSTEM_AppCompatCache.csv                                               into dataframe ->  output/json/ProgramExecution-Windows81_Windows2012R2_SYSTEM_AppCompatCache
#   + Reading csv file 20201116033206_Amcache_AssociatedFileEntries.csv                                                               into dataframe ->  output/json/ProgramExecution-Amcache_AssociatedFileEntries
#   + Reading csv file G__szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                                                into dataframe ->  output/json/FileFolderAccess-G__szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file G__szechuan_kape_artifacts_F_Users_Administrator_AppData_Local_Microsoft_Windows_UsrClass.dat.csv              into dataframe ->  output/json/FileFolderAccess-G__szechuan_kape_artifacts_F_Users_Administrator_AppData_Local_Microsoft_Windows_UsrClass.dat
#   + Reading csv file 20201116033239_RBCmd_Output.csv                                                                                into dataframe ->  output/json/FileDeletion-RBCmd
#   + Reading csv file 20201116033240_TimeZoneInfo_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM.csv                     into dataframe ->  output/json/Registry-TimeZoneInfo_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201116033240_FileExts_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                         into dataframe ->  output/json/Registry-FileExts_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033240_OpenSavePidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                  into dataframe ->  output/json/Registry-OpenSavePidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033240_CIDSizeMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                       into dataframe ->  output/json/Registry-CIDSizeMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033240_TerminalServerClient_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv             into dataframe ->  output/json/Registry-TerminalServerClient_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033240_MountedDevices_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM.csv                   into dataframe ->  output/json/Registry-MountedDevices_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201116033240_KnownNetworks_G_szechuan_kape_artifacts_F_Windows_system32_config_SOFTWARE.csv                  into dataframe ->  output/json/Registry-KnownNetworks_G_szechuan_kape_artifacts_F_Windows_system32_config_SOFTWARE
#   + Reading csv file 20201116033240_Services_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM.csv                         into dataframe ->  output/json/Registry-Services_G_szechuan_kape_artifacts_F_Windows_system32_config_SYSTEM
#   + Reading csv file 20201116033240_TypedURLs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                        into dataframe ->  output/json/Registry-TypedURLs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033240_UserAssist_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                       into dataframe ->  output/json/Registry-UserAssist_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033240_RecentDocs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv                       into dataframe ->  output/json/Registry-RecentDocs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033240_LastVisitedPidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv               into dataframe ->  output/json/Registry-LastVisitedPidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
#   + Reading csv file 20201116033240_RECmd_Batch_RECmd_Batch_MC_Output.csv                                                           into dataframe ->  output/json/Registry-RECmd_Batch_RECmd_Batch_MC
#
#
# NOTE: Now you can use the syntax <yourvar>['Category'] to access your dataframe
#
#
# - Reading Done.
#
# - Recover the object read by executing:  myvar = d4.out (e.g. mydf = d4.out)

# %%
kpdfs = d4.out

# %%
# Automatically created - DO NOT EDIT OR REMOVE unless you want to change the file to read (in that case, remove this cell)
# 2021-03-30 19:23:04.635037
# 20200918_0347_cdrive-ft-p03_kaped_f2read = "/mnt/analysis/cases/szechuan/f4n6/comps/20200918_0347_cdrive-ft-p03/kape"

# %% [markdown]
# ---

# %% [markdown]
# ## **ANALYSIS**

# %% [markdown]
# ### **GENERIC**

# %%
xdisplay()
# Out:
# #### Pandas options
# IntText(value=700, description='display.max_rows: ', style=DescriptionStyle(description_width='initial'))
# IntText(value=10, description='display.min_rows: ', style=DescriptionStyle(description_width='initial'))
# IntText(value=0, description='display.max_columns: ', style=DescriptionStyle(description_width='initial'))
# Dropdown(description='display.colheader_justify: ', index=1, options=('right', 'left'), style=DescriptionStyle…
# Checkbox(value=True, description='display.expand_frame_repr', indent=False, style=DescriptionStyle(description…

# %%
xmenu(kpdfs)
# Out:
# **DataFrame visualization menu:**
# Box(children=(Dropdown(description='Select DataFrame', layout=Layout(width='550px'), options=('Select DataFram…
# HBox(children=(Label(value='Selected dataframe: '),))
# HBox(children=(HTML(value="<div style='color: orange; font-weight: bold;'>Data Loading. Please Wait…</div>"),)…
# Output(layout=Layout(overflow='auto', width='99%'))
# Output(layout=Layout(overflow='auto', width='99%'))

# %%
df = d4.out

# %% [markdown]
# #### df.simple()

# %%
for category in kpdfs:
    print(category)
    kpdfs[category].simple()
    print('-------------------------------------------------------------------------------------------------------------')
# Out:
# artifacts-2020-11-16T033123_!SANS_Triage_copylog
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 230
# **Constant Columns**
#   Column            Value
# 0      D4_DataType_                                               nan
# 1  D4_Orchestrator_                                              kape
# 2          D4_Tool_                                              kape
# 3        D4_Plugin_  artifacts-2020-11-16T033123_!SANS_Triage_copylog
# 4      D4_Hostname_                       20200918_0347_cdrive-ft-p03
#     CopiedTimestamp      \
# 0   2020-11-16 03:31:27
# 1   2020-11-16 03:31:27
# 2   2020-11-16 03:31:27
# 3   2020-11-16 03:31:27
# 4   2020-11-16 03:31:27
# ..                  ...
# 225 2020-11-16 03:31:30
# 226 2020-11-16 03:31:30
# 227 2020-11-16 03:31:30
# 228 2020-11-16 03:31:30
# 229 2020-11-16 03:31:30
#
#     SourceFile                                                                          \
# 0                   F:\Windows\system32\winevt\logs\Active Directory Web Services.evtx
# 1                                     F:\Windows\system32\winevt\logs\Application.evtx
# 2                                 F:\Windows\system32\winevt\logs\DFS Replication.evtx
# 3                               F:\Windows\system32\winevt\logs\Directory Service.evtx
# 4                                      F:\Windows\system32\winevt\logs\DNS Server.evtx
# ..                                                                                 ...
# 225  F:\Windows\system32\Tasks\Microsoft\Windows\WindowsColorSystem\Calibration Loader
# 226        F:\Windows\system32\Tasks\Microsoft\Windows\WindowsUpdate\AUFirmwareInstall
# 227       F:\Windows\system32\Tasks\Microsoft\Windows\WindowsUpdate\AUScheduledInstall
# 228         F:\Windows\system32\Tasks\Microsoft\Windows\WindowsUpdate\AUSessionConnect
# 229                           F:\Windows\system32\Tasks\Microsoft\Windows\WindowsUpdat
#
#     DestinationFile                                                                                               \
# 0                   G:\szechuan\kape\artifacts\F\Windows\system32\winevt\logs\Active Directory Web Services.evtx
# 1                                     G:\szechuan\kape\artifacts\F\Windows\system32\winevt\logs\Application.evtx
# 2                                 G:\szechuan\kape\artifacts\F\Windows\system32\winevt\logs\DFS Replication.evtx
# 3                               G:\szechuan\kape\artifacts\F\Windows\system32\winevt\logs\Directory Service.evtx
# 4                                      G:\szechuan\kape\artifacts\F\Windows\system32\winevt\logs\DNS Server.evtx
# ..                                                                                                           ...
# 225  G:\szechuan\kape\artifacts\F\Windows\system32\Tasks\Microsoft\Windows\WindowsColorSystem\Calibration Loader
# 226        G:\szechuan\kape\artifacts\F\Windows\system32\Tasks\Microsoft\Windows\WindowsUpdate\AUFirmwareInstall
# 227       G:\szechuan\kape\artifacts\F\Windows\system32\Tasks\Microsoft\Windows\WindowsUpdate\AUScheduledInstall
# 228         G:\szechuan\kape\artifacts\F\Windows\system32\Tasks\Microsoft\Windows\WindowsUpdate\AUSessionConnect
# 229                                                                                                         <NA>
#
#      FileSize SourceFileSha1                             DeferredCopy  \
# 0      69632   3E746EAD1815EC63F4156E08FA2DEB08C5DD46DE  False
# 1    1118208   CFDC939050F78F6520D8C54A3060DAE92A4A49BF  False
# 2      69632   A2E01C3DD5ADCD0D4EA65BB03D84C4BED04C197E  False
# 3      69632   78A33B0B5DEDFAE67A8C0A92F96FE71DC6C9206A  False
# 4      69632   E94B640604F9FA9CE94CBCDF60A744C64EC7E7A5  False
# ..        ...                                       ...           ...
# 225     3532   6001C7A68E0BC2E160B4C1E8C767B259A1D7D948  False
# 226     3500   16B6962052A3453B29A708E08DFFD0257FE5424F  False
# 227     3392   8886DF71ECB07321E77E8FB8BA82CCD9C97D9EC6  False
# 228     4992   4A74ECE002DFD2B69C9ED183A7DCA19F06AF244F  False
# 229     <NA>                                       <NA>   <NA>
#
#     CreatedOnUtc        ModifiedOnUtc       LastAccessedOnUtc    \
# 0   2020-09-17 17:51:38 2020-09-19 01:23:58 2020-11-16 03:29:56
# 1   2020-09-17 15:52:01 2020-09-19 01:23:42 2020-11-16 03:29:56
# 2   2020-09-17 17:51:38 2020-09-19 01:23:58 2020-11-16 03:29:56
# 3   2020-09-17 17:51:38 2020-09-19 01:23:42 2020-11-16 03:29:56
# 4   2020-09-17 17:51:38 2020-09-19 01:24:03 2020-11-16 03:29:56
# ..                  ...                 ...                 ...
# 225 2013-08-22 15:41:04 2013-08-22 14:50:28 2020-11-16 03:29:59
# 226 2013-08-22 15:40:15 2013-08-22 15:40:15 2020-11-16 03:29:59
# 227 2013-08-22 15:40:15 2020-09-19 01:33:23 2020-11-16 03:29:59
# 228 2013-08-22 15:40:15 2020-09-19 01:33:23 2020-11-16 03:29:59
# 229                 NaT                 NaT                 NaT
#
#     CopyDuration
# 0   2021-04-06 00:00:00
# 1   2021-04-06 00:00:00
# 2   2021-04-06 00:00:00
# 3   2021-04-06 00:00:01
# 4   2021-04-06 00:00:00
# ..                  ...
# 225 2021-04-06 00:00:00
# 226 2021-04-06 00:00:00
# 227 2021-04-06 00:00:01
# 228 2021-04-06 00:00:00
# 229                 NaT
#
# [230 rows x 10 columns]
# -------------------------------------------------------------------------------------------------------------
# artifacts-2020-11-16T033123_!SANS_Triage_skiplog
# <IPython.core.display.Markdown object>
# -------------------------------------------------------------------------------------------------------------
# output/csv/FileFolderAccess-AutomaticDestinations
# **Statistics:**
# <br>No. Entries: 9
# **Constant Columns**
#    Column            Value
# 0       D4_DataType_                                                nan
# 1   D4_Orchestrator_                                               kape
# 2           D4_Tool_                                               kape
# 3         D4_Plugin_  output/csv/FileFolderAccess-AutomaticDestinations
# 4       D4_Hostname_                        20200918_0347_cdrive-ft-p03
# 5     SourceAccessed                                2020-11-16 03:30:46
# 6    DestListVersion                                                  1
# 7   InteractionCount                                                  0
# 8          PinStatus                                              False
# 9       RelativePath                                               <NA>
# 10  WorkingDirectory                                               <NA>
# 11       VolumeLabel                                               <NA>
# 12             Notes                                               <NA>
# <style  type="text/css" >
# #T_178f1_row0_col0,#T_178f1_row0_col1,#T_178f1_row0_col2,#T_178f1_row0_col3,#T_178f1_row0_col4,#T_178f1_row0_col5,#T_178f1_row0_col6,#T_178f1_row0_col7,#T_178f1_row0_col8,#T_178f1_row0_col9,#T_178f1_row0_col10,#T_178f1_row0_col11,#T_178f1_row0_col12,#T_178f1_row0_col13,#T_178f1_row0_col14,#T_178f1_row0_col15,#T_178f1_row0_col16,#T_178f1_row0_col17,#T_178f1_row0_col18,#T_178f1_row0_col19,#T_178f1_row0_col20,#T_178f1_row0_col21,#T_178f1_row0_col22,#T_178f1_row0_col23,#T_178f1_row0_col24,#T_178f1_row0_col25,#T_178f1_row0_col26,#T_178f1_row0_col27,#T_178f1_row0_col28,#T_178f1_row0_col29,#T_178f1_row0_col30,#T_178f1_row0_col31,#T_178f1_row0_col32,#T_178f1_row0_col33,#T_178f1_row0_col34,#T_178f1_row0_col35,#T_178f1_row1_col0,#T_178f1_row1_col1,#T_178f1_row1_col2,#T_178f1_row1_col3,#T_178f1_row1_col4,#T_178f1_row1_col5,#T_178f1_row1_col6,#T_178f1_row1_col7,#T_178f1_row1_col8,#T_178f1_row1_col9,#T_178f1_row1_col10,#T_178f1_row1_col11,#T_178f1_row1_col12,#T_178f1_row1_col13,#T_178f1_row1_col14,#T_178f1_row1_col15,#T_178f1_row1_col16,#T_178f1_row1_col17,#T_178f1_row1_col18,#T_178f1_row1_col19,#T_178f1_row1_col20,#T_178f1_row1_col21,#T_178f1_row1_col22,#T_178f1_row1_col23,#T_178f1_row1_col24,#T_178f1_row1_col25,#T_178f1_row1_col26,#T_178f1_row1_col27,#T_178f1_row1_col28,#T_178f1_row1_col29,#T_178f1_row1_col30,#T_178f1_row1_col31,#T_178f1_row1_col32,#T_178f1_row1_col33,#T_178f1_row1_col34,#T_178f1_row1_col35,#T_178f1_row2_col0,#T_178f1_row2_col1,#T_178f1_row2_col2,#T_178f1_row2_col3,#T_178f1_row2_col4,#T_178f1_row2_col5,#T_178f1_row2_col6,#T_178f1_row2_col7,#T_178f1_row2_col8,#T_178f1_row2_col9,#T_178f1_row2_col10,#T_178f1_row2_col11,#T_178f1_row2_col12,#T_178f1_row2_col13,#T_178f1_row2_col14,#T_178f1_row2_col15,#T_178f1_row2_col16,#T_178f1_row2_col17,#T_178f1_row2_col18,#T_178f1_row2_col19,#T_178f1_row2_col20,#T_178f1_row2_col21,#T_178f1_row2_col22,#T_178f1_row2_col23,#T_178f1_row2_col24,#T_178f1_row2_col25,#T_178f1_row2_col26,#T_178f1_row2_col27,#T_178f1_row2_col28,#T_178f1_row2_col29,#T_178f1_row2_col30,#T_178f1_row2_col31,#T_178f1_row2_col32,#T_178f1_row2_col33,#T_178f1_row2_col34,#T_178f1_row2_col35,#T_178f1_row3_col0,#T_178f1_row3_col1,#T_178f1_row3_col2,#T_178f1_row3_col3,#T_178f1_row3_col4,#T_178f1_row3_col5,#T_178f1_row3_col6,#T_178f1_row3_col7,#T_178f1_row3_col8,#T_178f1_row3_col9,#T_178f1_row3_col10,#T_178f1_row3_col11,#T_178f1_row3_col12,#T_178f1_row3_col13,#T_178f1_row3_col14,#T_178f1_row3_col15,#T_178f1_row3_col16,#T_178f1_row3_col17,#T_178f1_row3_col18,#T_178f1_row3_col19,#T_178f1_row3_col20,#T_178f1_row3_col21,#T_178f1_row3_col22,#T_178f1_row3_col23,#T_178f1_row3_col24,#T_178f1_row3_col25,#T_178f1_row3_col26,#T_178f1_row3_col27,#T_178f1_row3_col28,#T_178f1_row3_col29,#T_178f1_row3_col30,#T_178f1_row3_col31,#T_178f1_row3_col32,#T_178f1_row3_col33,#T_178f1_row3_col34,#T_178f1_row3_col35,#T_178f1_row4_col0,#T_178f1_row4_col1,#T_178f1_row4_col2,#T_178f1_row4_col3,#T_178f1_row4_col4,#T_178f1_row4_col5,#T_178f1_row4_col6,#T_178f1_row4_col7,#T_178f1_row4_col8,#T_178f1_row4_col9,#T_178f1_row4_col10,#T_178f1_row4_col11,#T_178f1_row4_col12,#T_178f1_row4_col13,#T_178f1_row4_col14,#T_178f1_row4_col15,#T_178f1_row4_col16,#T_178f1_row4_col17,#T_178f1_row4_col18,#T_178f1_row4_col19,#T_178f1_row4_col20,#T_178f1_row4_col21,#T_178f1_row4_col22,#T_178f1_row4_col23,#T_178f1_row4_col24,#T_178f1_row4_col25,#T_178f1_row4_col26,#T_178f1_row4_col27,#T_178f1_row4_col28,#T_178f1_row4_col29,#T_178f1_row4_col30,#T_178f1_row4_col31,#T_178f1_row4_col32,#T_178f1_row4_col33,#T_178f1_row4_col34,#T_178f1_row4_col35,#T_178f1_row5_col0,#T_178f1_row5_col1,#T_178f1_row5_col2,#T_178f1_row5_col3,#T_178f1_row5_col4,#T_178f1_row5_col5,#T_178f1_row5_col6,#T_178f1_row5_col7,#T_178f1_row5_col8,#T_178f1_row5_col9,#T_178f1_row5_col10,#T_178f1_row5_col11,#T_178f1_row5_col12,#T_178f1_row5_col13,#T_178f1_row5_col14,#T_178f1_row5_col15,#T_178f1_row5_col16,#T_178f1_row5_col17,#T_178f1_row5_col18,#T_178f1_row5_col19,#T_178f1_row5_col20,#T_178f1_row5_col21,#T_178f1_row5_col22, ...
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_178f1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >SourceFile</th>        <th class="col_heading level0 col2" >SourceCreated</th>        <th class="col_heading level0 col3" >SourceModified</th>        <th class="col_heading level0 col4" >AppId</th>        <th class="col_heading level0 col5" >AppIdDescription</th>        <th class="col_heading level0 col6" >LastUsedEntryNumber</th>        <th class="col_heading level0 col7" >MRU</th>        <th class="col_heading level0 col8" >EntryNumber</th>        <th class="col_heading level0 col9" >CreationTime</th>        <th class="col_heading level0 col10" >LastModified</th>        <th class="col_heading level0 col11" >Hostname</th>        <th class="col_heading level0 col12" >MacAddress</th>        <th class="col_heading level0 col13" >Path</th>        <th class="col_heading level0 col14" >FileBirthDroid</th>        <th class="col_heading level0 col15" >FileDroid</th>        <th class="col_heading level0 col16" >VolumeBirthDroid</th>        <th class="col_heading level0 col17" >VolumeDroid</th>        <th class="col_heading level0 col18" >TargetCreated</th>        <th class="col_heading level0 col19" >TargetModified</th>        <th class="col_heading level0 col20" >TargetAccessed</th>        <th class="col_heading level0 col21" >FileSize</th>        <th class="col_heading level0 col22" >FileAttributes</th>
# -------------------------------------------------------------------------------------------------------------
# output/csv/FileFolderAccess-CustomDestinations
# **Statistics:**
# <br>No. Entries: 6
# **Constant Columns**
#    Column                   Value
# 0              D4_DataType_                                             nan
# 1          D4_Orchestrator_                                            kape
# 2                  D4_Tool_                                            kape
# 3                D4_Plugin_  output/csv/FileFolderAccess-CustomDestinations
# 4              D4_Hostname_                     20200918_0347_cdrive-ft-p03
# 5            SourceAccessed                             2020-11-16 03:30:46
# 6                 EntryName                                            <NA>
# 7              RelativePath                                            <NA>
# 8          WorkingDirectory                                            <NA>
# 9            FileAttributes                            FileAttributeArchive
# 10                DriveType                Fixed storage media (Hard drive)
# 11       VolumeSerialNumber                                        E648FAD0
# 12              VolumeLabel                                            <NA>
# 13               CommonPath                                            <NA>
# 14  TargetMFTSequenceNumber                                             0x1
# 15                MachineID                                    citadel-dc01
# <style  type="text/css" >
# #T_65309_row0_col0,#T_65309_row0_col1,#T_65309_row0_col2,#T_65309_row0_col3,#T_65309_row0_col4,#T_65309_row0_col5,#T_65309_row0_col6,#T_65309_row0_col7,#T_65309_row0_col8,#T_65309_row0_col9,#T_65309_row0_col10,#T_65309_row0_col11,#T_65309_row0_col12,#T_65309_row0_col13,#T_65309_row0_col14,#T_65309_row0_col15,#T_65309_row0_col16,#T_65309_row0_col17,#T_65309_row1_col0,#T_65309_row1_col1,#T_65309_row1_col2,#T_65309_row1_col3,#T_65309_row1_col4,#T_65309_row1_col5,#T_65309_row1_col6,#T_65309_row1_col7,#T_65309_row1_col8,#T_65309_row1_col9,#T_65309_row1_col10,#T_65309_row1_col11,#T_65309_row1_col12,#T_65309_row1_col13,#T_65309_row1_col14,#T_65309_row1_col15,#T_65309_row1_col16,#T_65309_row1_col17,#T_65309_row2_col0,#T_65309_row2_col1,#T_65309_row2_col2,#T_65309_row2_col3,#T_65309_row2_col4,#T_65309_row2_col5,#T_65309_row2_col6,#T_65309_row2_col7,#T_65309_row2_col8,#T_65309_row2_col9,#T_65309_row2_col10,#T_65309_row2_col11,#T_65309_row2_col12,#T_65309_row2_col13,#T_65309_row2_col14,#T_65309_row2_col15,#T_65309_row2_col16,#T_65309_row2_col17,#T_65309_row3_col0,#T_65309_row3_col1,#T_65309_row3_col2,#T_65309_row3_col3,#T_65309_row3_col4,#T_65309_row3_col5,#T_65309_row3_col6,#T_65309_row3_col7,#T_65309_row3_col8,#T_65309_row3_col9,#T_65309_row3_col10,#T_65309_row3_col11,#T_65309_row3_col12,#T_65309_row3_col13,#T_65309_row3_col14,#T_65309_row3_col15,#T_65309_row3_col16,#T_65309_row3_col17,#T_65309_row4_col0,#T_65309_row4_col1,#T_65309_row4_col2,#T_65309_row4_col3,#T_65309_row4_col4,#T_65309_row4_col5,#T_65309_row4_col6,#T_65309_row4_col7,#T_65309_row4_col8,#T_65309_row4_col9,#T_65309_row4_col10,#T_65309_row4_col11,#T_65309_row4_col12,#T_65309_row4_col13,#T_65309_row4_col14,#T_65309_row4_col15,#T_65309_row4_col16,#T_65309_row4_col17,#T_65309_row5_col0,#T_65309_row5_col1,#T_65309_row5_col2,#T_65309_row5_col3,#T_65309_row5_col4,#T_65309_row5_col5,#T_65309_row5_col6,#T_65309_row5_col7,#T_65309_row5_col8,#T_65309_row5_col9,#T_65309_row5_col10,#T_65309_row5_col11,#T_65309_row5_col12,#T_65309_row5_col13,#T_65309_row5_col14,#T_65309_row5_col15,#T_65309_row5_col16,#T_65309_row5_col17{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_65309_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >SourceFile</th>        <th class="col_heading level0 col2" >SourceCreated</th>        <th class="col_heading level0 col3" >SourceModified</th>        <th class="col_heading level0 col4" >AppId</th>        <th class="col_heading level0 col5" >AppIdDescription</th>        <th class="col_heading level0 col6" >TargetCreated</th>        <th class="col_heading level0 col7" >TargetModified</th>        <th class="col_heading level0 col8" >TargetAccessed</th>        <th class="col_heading level0 col9" >FileSize</th>        <th class="col_heading level0 col10" >HeaderFlags</th>        <th class="col_heading level0 col11" >LocalPath</th>        <th class="col_heading level0 col12" >TargetIDAbsolutePath</th>        <th class="col_heading level0 col13" >TargetMFTEntryNumber</th>        <th class="col_heading level0 col14" >MachineMACAddress</th>        <th class="col_heading level0 col15" >TrackerCreatedOn</th>        <th class="col_heading level0 col16" >ExtraBlocksPresent</th>        <th class="col_heading level0 col17" >Arguments</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_65309_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_65309_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_65309_row0_col1" class="data row0 col1" >G:\szechuan\kape\artifacts\F\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\28c8b86deab549a1.customDestinations-ms</td>
#                         <td id="T_65309_row0_col2" class="data row0 col2" >2020-09-19 03:30:27</td>
#                         <td id="T_65309_row0_col3" class="data row0 col3" >2020-09-19 03:30:27</td>
#                         <td id="T_65309_row0_col4" class="data row0 col4" >28c8b86deab549a1</td>
#                         <td id="T_65309_row0_col5" class="data row0 col5" >Internet Explorer 8.0.7600.16385 / 9</td>
#                         <td id="T_65309_row0_col6" class="data row0 col6" >2014-03-21 19:02:52</td>
#                         <td id="T_65309_row0_col7" class="data row0 col7" >2014-03-21 19:02:52</td>
#                         <td id="T_65309_row0_col8" class="data row0 col8" >2014-03-21 19:02:52</td>
#                         <td id="T_65309_row0_col9" class="data row0 col9" >809648</td>
#                         <td id="T_65309_row0_col10" class="data row0 col10" >HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon, DisableKnownFolderTracking, AllowLinkToLink</td>
#                         <td id="T_65309_row0_col11" class="data row0 col11" >C:\Program Files\Internet Explorer\iexplore.exe</td>
#                         <td id="T_65309_row0_col12" class="data row0 col12" >My Computer\C:\Program Files\Internet Explorer\iexplore.exe</td>
#                         <td id="T_65309_row0_col13" class="data row0 col13" >0x11E4B</td>
#                         <td id="T_65309_row0_col14" class="data row0 col14" >00:15:5d:8a:ac:72</td>
#                         <td id="T_65309_row0_col15" class="data row0 col15" >2014-03-21 19:09:10</td>
#                         <td id="T_65309_row0_col16" class="data row0 col16" >IconEnvironmentDataBlock, PropertyStoreDataBlock, TrackerDataBaseBlock</td>
#                         <td id="T_65309_row0_col17" class="data row0 col17" >-private</td>
#             </tr>
#             <tr>
#                         <th id="T_65309_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_65309_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_65309_row1_col1" class="data row1 col1" >G:\szechuan\kape\artifacts\F\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\CustomDestinations\28c8b86deab549a1.customDestinations-ms</td>
#                         <td id="T_65309_row1_col2" class="data row1 col2" >2020-09-19 03:30:27</td>
#                         <td id="T_65309_row1_col3" class="data row1 col3" >2020-09-19 03:30:27</td>
#                         <td id="T_65309_row1_col4" class="data row1 col4" >28c8b86deab549a1</td>
#                         <td id="T_65309_row1_col5" class="data row1 col5" >Internet Explorer 8.0.7600.16385 / 9</td>
#                         <td id="T_65309_row1_col6" class="data row1 col6" >2014-03-21 19:02:52</td>
#                         <td id="T_65309_row1_col7" class="data row1 col7" >2014-03-21 19:02:52</td>
#                         <td id="T_65309_row1_col8" class="data row1 col8" >2014-03-21 19:02:52</td>
#                         <td id="T_65309_row1_col9" class="data row1 col9" >809648</td>
#                         <td id="T_65309_row1_col10" class="data row1 col10" >HasTargetIdList, HasLinkInfo, HasArguments, HasIconLocation, IsUnicode, HasExpIcon, DisableKnownFolderTracking, AllowLinkToLink</td>
#                         <td id="T_65309_row1_col11" class="data row1 col11" >C:\Program Files\Internet Explorer\iexplore.exe</td>
#                         <td id="T_65309_row1_col12" class="data row1 col12" >My Computer\C:\Program Files\Internet Explorer\iexplore.exe</td>
#                         <td id="T_65309_row1_col13" class="data row1 col13" >0x11E4B</td>
#                         <td id="T_65309_row1_col14" class="data row1 col14" >00:15:5d:8a:ac:72</td>
#                         <td id="T_65309_row1_col15" class="data row1 col15" >2014-03-21 19:09:10</td>
#                         <td id="T_65309_row1_col16" class="data row1 col16" >IconEnvironmentDataBlock, PropertyStoreDataBlock, TrackerDataBaseBlock</td>
#                         <td id="T_65309_row1_col17" class="data row1 col17" >-newtab</td>
#             </tr>
#             <tr>
# -------------------------------------------------------------------------------------------------------------
# output/csv/FileFolderAccess-G__szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
# <IPython.core.display.Markdown object>
# -------------------------------------------------------------------------------------------------------------
# output/csv/FileFolderAccess-LECmd
# **Statistics:**
# <br>No. Entries: 13
# **Constant Columns**
#   Column            Value
# 0      D4_DataType_                                nan
# 1  D4_Orchestrator_                               kape
# 2          D4_Tool_                               kape
# 3        D4_Plugin_  output/csv/FileFolderAccess-LECmd
# 4      D4_Hostname_        20200918_0347_cdrive-ft-p03
# 5    SourceAccessed                2020-11-16 03:30:46
# <style  type="text/css" >
# #T_d5cc0_row0_col0,#T_d5cc0_row0_col1,#T_d5cc0_row0_col2,#T_d5cc0_row0_col3,#T_d5cc0_row0_col4,#T_d5cc0_row0_col5,#T_d5cc0_row0_col6,#T_d5cc0_row0_col7,#T_d5cc0_row0_col8,#T_d5cc0_row0_col9,#T_d5cc0_row0_col10,#T_d5cc0_row0_col11,#T_d5cc0_row0_col12,#T_d5cc0_row0_col13,#T_d5cc0_row0_col14,#T_d5cc0_row0_col15,#T_d5cc0_row0_col16,#T_d5cc0_row0_col17,#T_d5cc0_row0_col18,#T_d5cc0_row0_col19,#T_d5cc0_row0_col20,#T_d5cc0_row0_col21,#T_d5cc0_row0_col22,#T_d5cc0_row0_col23,#T_d5cc0_row0_col24,#T_d5cc0_row0_col25,#T_d5cc0_row0_col26,#T_d5cc0_row1_col0,#T_d5cc0_row1_col1,#T_d5cc0_row1_col2,#T_d5cc0_row1_col3,#T_d5cc0_row1_col4,#T_d5cc0_row1_col5,#T_d5cc0_row1_col6,#T_d5cc0_row1_col7,#T_d5cc0_row1_col8,#T_d5cc0_row1_col9,#T_d5cc0_row1_col10,#T_d5cc0_row1_col11,#T_d5cc0_row1_col12,#T_d5cc0_row1_col13,#T_d5cc0_row1_col14,#T_d5cc0_row1_col15,#T_d5cc0_row1_col16,#T_d5cc0_row1_col17,#T_d5cc0_row1_col18,#T_d5cc0_row1_col19,#T_d5cc0_row1_col20,#T_d5cc0_row1_col21,#T_d5cc0_row1_col22,#T_d5cc0_row1_col23,#T_d5cc0_row1_col24,#T_d5cc0_row1_col25,#T_d5cc0_row1_col26,#T_d5cc0_row2_col0,#T_d5cc0_row2_col1,#T_d5cc0_row2_col2,#T_d5cc0_row2_col3,#T_d5cc0_row2_col4,#T_d5cc0_row2_col5,#T_d5cc0_row2_col6,#T_d5cc0_row2_col7,#T_d5cc0_row2_col8,#T_d5cc0_row2_col9,#T_d5cc0_row2_col10,#T_d5cc0_row2_col11,#T_d5cc0_row2_col12,#T_d5cc0_row2_col13,#T_d5cc0_row2_col14,#T_d5cc0_row2_col15,#T_d5cc0_row2_col16,#T_d5cc0_row2_col17,#T_d5cc0_row2_col18,#T_d5cc0_row2_col19,#T_d5cc0_row2_col20,#T_d5cc0_row2_col21,#T_d5cc0_row2_col22,#T_d5cc0_row2_col23,#T_d5cc0_row2_col24,#T_d5cc0_row2_col25,#T_d5cc0_row2_col26,#T_d5cc0_row3_col0,#T_d5cc0_row3_col1,#T_d5cc0_row3_col2,#T_d5cc0_row3_col3,#T_d5cc0_row3_col4,#T_d5cc0_row3_col5,#T_d5cc0_row3_col6,#T_d5cc0_row3_col7,#T_d5cc0_row3_col8,#T_d5cc0_row3_col9,#T_d5cc0_row3_col10,#T_d5cc0_row3_col11,#T_d5cc0_row3_col12,#T_d5cc0_row3_col13,#T_d5cc0_row3_col14,#T_d5cc0_row3_col15,#T_d5cc0_row3_col16,#T_d5cc0_row3_col17,#T_d5cc0_row3_col18,#T_d5cc0_row3_col19,#T_d5cc0_row3_col20,#T_d5cc0_row3_col21,#T_d5cc0_row3_col22,#T_d5cc0_row3_col23,#T_d5cc0_row3_col24,#T_d5cc0_row3_col25,#T_d5cc0_row3_col26,#T_d5cc0_row4_col0,#T_d5cc0_row4_col1,#T_d5cc0_row4_col2,#T_d5cc0_row4_col3,#T_d5cc0_row4_col4,#T_d5cc0_row4_col5,#T_d5cc0_row4_col6,#T_d5cc0_row4_col7,#T_d5cc0_row4_col8,#T_d5cc0_row4_col9,#T_d5cc0_row4_col10,#T_d5cc0_row4_col11,#T_d5cc0_row4_col12,#T_d5cc0_row4_col13,#T_d5cc0_row4_col14,#T_d5cc0_row4_col15,#T_d5cc0_row4_col16,#T_d5cc0_row4_col17,#T_d5cc0_row4_col18,#T_d5cc0_row4_col19,#T_d5cc0_row4_col20,#T_d5cc0_row4_col21,#T_d5cc0_row4_col22,#T_d5cc0_row4_col23,#T_d5cc0_row4_col24,#T_d5cc0_row4_col25,#T_d5cc0_row4_col26,#T_d5cc0_row5_col0,#T_d5cc0_row5_col1,#T_d5cc0_row5_col2,#T_d5cc0_row5_col3,#T_d5cc0_row5_col4,#T_d5cc0_row5_col5,#T_d5cc0_row5_col6,#T_d5cc0_row5_col7,#T_d5cc0_row5_col8,#T_d5cc0_row5_col9,#T_d5cc0_row5_col10,#T_d5cc0_row5_col11,#T_d5cc0_row5_col12,#T_d5cc0_row5_col13,#T_d5cc0_row5_col14,#T_d5cc0_row5_col15,#T_d5cc0_row5_col16,#T_d5cc0_row5_col17,#T_d5cc0_row5_col18,#T_d5cc0_row5_col19,#T_d5cc0_row5_col20,#T_d5cc0_row5_col21,#T_d5cc0_row5_col22,#T_d5cc0_row5_col23,#T_d5cc0_row5_col24,#T_d5cc0_row5_col25,#T_d5cc0_row5_col26,#T_d5cc0_row6_col0,#T_d5cc0_row6_col1,#T_d5cc0_row6_col2,#T_d5cc0_row6_col3,#T_d5cc0_row6_col4,#T_d5cc0_row6_col5,#T_d5cc0_row6_col6,#T_d5cc0_row6_col7,#T_d5cc0_row6_col8,#T_d5cc0_row6_col9,#T_d5cc0_row6_col10,#T_d5cc0_row6_col11,#T_d5cc0_row6_col12,#T_d5cc0_row6_col13,#T_d5cc0_row6_col14,#T_d5cc0_row6_col15,#T_d5cc0_row6_col16,#T_d5cc0_row6_col17,#T_d5cc0_row6_col18,#T_d5cc0_row6_col19,#T_d5cc0_row6_col20,#T_d5cc0_row6_col21,#T_d5cc0_row6_col22,#T_d5cc0_row6_col23,#T_d5cc0_row6_col24,#T_d5cc0_row6_col25,#T_d5cc0_row6_col26,#T_d5cc0_row7_col0,#T_d5cc0_row7_col1,#T_d5cc0_row7_col2,#T_d5cc0_row7_col3,#T_d5cc0_row7_col4,#T_d5cc0_row7_col5,#T_d5cc0_row7_col6,#T_d5cc0_row7_col7,#T_d5cc0_row7_col8,#T_d5cc0_row7_col9,#T_d5cc0_row7_col10,#T_d5cc0_row7_col11,#T_d5cc0_row7_col12,#T_d5cc0_row7_col13,#T_d5cc0_row7_col14, ...
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_d5cc0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >SourceFile</th>        <th class="col_heading level0 col2" >SourceCreated</th>        <th class="col_heading level0 col3" >SourceModified</th>        <th class="col_heading level0 col4" >TargetCreated</th>        <th class="col_heading level0 col5" >TargetModified</th>        <th class="col_heading level0 col6" >TargetAccessed</th>        <th class="col_heading level0 col7" >FileSize</th>        <th class="col_heading level0 col8" >RelativePath</th>        <th class="col_heading level0 col9" >WorkingDirectory</th>        <th class="col_heading level0 col10" >FileAttributes</th>        <th class="col_heading level0 col11" >HeaderFlags</th>        <th class="col_heading level0 col12" >DriveType</th>        <th class="col_heading level
# -------------------------------------------------------------------------------------------------------------
# output/csv/FileFolderAccess-G__szechuan_kape_artifacts_F_Users_Administrator_AppData_Local_Microsoft_Windows_UsrClass.dat
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 27
# **Constant Columns**
#   Column             \
# 0      D4_DataType_
# 1  D4_Orchestrator_
# 2          D4_Tool_
# 3        D4_Plugin_
# 4      D4_Hostname_
#
#   Value
# 0                                                                                                                        nan
# 1                                                                                                                       kape
# 2                                                                                                                       kape
# 3  output/csv/FileFolderAccess-G__szechuan_kape_artifacts_F_Users_Administrator_AppData_Local_Microsoft_Windows_UsrClass.dat
# 4                                                                                                20200918_0347_cdrive-ft-p03
#    BagPath      Slot  NodeSlot  MRUPosition  \
# 0       BagMRU  0      0        0
# 1       BagMRU  1      0        1
# 2     BagMRU\0  0      5        1
# 3     BagMRU\0  1      9        2
# 4     BagMRU\0  2     23        0
# ..         ...   ...       ...          ...
# 22    BagMRU\1  0      0        1
# 23    BagMRU\1  1      0        0
# 24  BagMRU\1\0  0      2        1
# 25  BagMRU\1\0  1      3        0
# 26  BagMRU\1\1  0      4        0
#
#    AbsolutePath                                                            \
# 0                                                     Desktop\My Computer
# 1                                                   Desktop\Control Panel
# 2                                                  Desktop\My Computer\C:
# 3                                           Desktop\My Computer\Downloads
# 4                                                  Desktop\My Computer\E:
# ..                                                                    ...
# 22                             Desktop\Control Panel\Network and Internet
# 23                              Desktop\Control Panel\System and Security
# 24  Desktop\Control Panel\Network and Internet\Network and Sharing Center
# 25         Desktop\Control Panel\Network and Internet\Network Connections
# 26                       Desktop\Control Panel\System and Security\System
#
#    ShellType               Value                        ChildBags CreatedOn  \
# 0        Root folder: GUID                 My Computer  3          <NA>
# 1        Root folder: GUID               Control Panel  2          <NA>
# 2             Drive letter                          C:  3          <NA>
# 3        Root folder: GUID                   Downloads  0          <NA>
# 4             Drive letter                          E:  1          <NA>
# ..                     ...                         ...        ...       ...
# 22  Control Panel Category        Network and Internet  2          <NA>
# 23  Control Panel Category         System and Security  1          <NA>
# 24     GUID: Control panel  Network and Sharing Center  0          <NA>
# 25     GUID: Control panel         Network Connections  0          <NA>
# 26     GUID: Control panel                      System  0          <NA>
#
#    ModifiedOn AccessedOn LastWriteTime        MFTEntry  MFTSequenceNumber  \
# 0   <NA>       <NA>      2020-09-19 04:36:59  <NA>      <NA>
# 1   <NA>       <NA>      2020-09-19 04:36:59  <NA>      <NA>
# 2   <NA>       <NA>      2020-09-19 04:36:53  <NA>      <NA>
# 3   <NA>       <NA>      2020-09-19 04:36:53  <NA>      <NA>
# 4   <NA>       <NA>      2020-09-19 04:36:53  <NA>      <NA>
# ..        ...        ...                 ...       ...                ...
# 22  <NA>       <NA>      2020-09-18 22:26:52  <NA>      <NA>
# 23  <NA>       <NA>      2020-09-18 22:26:52  <NA>      <NA>
# 24  <NA>       <NA>      2020-09-18 00:44:13  <NA>      <NA>
# 25  <NA>       <NA>      2020-09-18 00:44:13  <NA>      <NA>
# 26  <NA>       <NA>      2020-09-18 22:26:52  <NA>      <NA>
#
#     ExtensionBlockCount FirstInteracted      LastInteracted      Miscellaneous
# 0   0                                   <NA> 2020-09-19 04:36:59  <NA>
# 1   0                                   <NA>                 NaT  <NA>
# 2   0                                   <NA>                 NaT  <NA>
# 3   0                    2020-09-19 03:24:06                 NaT  <NA>
# 4   0                                   <NA> 2020-09-19 04:36:53  <NA>
# ..                  ...                  ...                 ...           ...
# 22  0                                   <NA>                 NaT  <NA>
# 23  0                                   <NA> 2020-09-18 22:26:52  <NA>
# 24  0                    2020-09-17 17:07:16                 NaT  <NA>
# 25  0                    2020-09-18 00:44:13 2020-09-18 00:44:13  <NA>
# 26  0                    2020-09-18 22:26:52 2020-09-18 22:26:52  <NA>
#
# [27 rows x 18 columns]
# -------------------------------------------------------------------------------------------------------------
# output/csv/ProgramExecution-Amcache_ProgramEntries
# **Statistics:**
# <br>No. Entries: 3
# **Constant Columns**
#    Column              Value
# 0         D4_DataType_                                                 nan
# 1     D4_Orchestrator_                                                kape
# 2             D4_Tool_                                                kape
# 3           D4_Plugin_  output/csv/ProgramExecution-Amcache_ProgramEntries
# 4         D4_Hostname_                         20200918_0347_cdrive-ft-p03
# 5   LastWriteTimestamp                                 2020-09-18 22:37:30
# 6   InstallDateEpoch_a                                 2020-09-18 22:37:30
# 7       LanguageCode_3                                    AddRemoveProgram
# 8     UninstallGuid_11                                                 256
# 9       UnknownDword_5                                                   0
# 10     UnknownDword_13                                                   0
# 11     UnknownDword_14                                                   0
# 12     UnknownDword_15                                                  0x
# 13     UnknownBytes_16                                                   0
# 14     UnknownQWord_17                                                   0
# 15     UninstallGuid_f                                                <NA>
# <style  type="text/css" >
# #T_8a599_row0_col0,#T_8a599_row0_col1,#T_8a599_row0_col2,#T_8a599_row0_col3,#T_8a599_row0_col4,#T_8a599_row0_col5,#T_8a599_row0_col6,#T_8a599_row0_col7,#T_8a599_row0_col8,#T_8a599_row0_col9,#T_8a599_row0_col10,#T_8a599_row0_col11,#T_8a599_row1_col0,#T_8a599_row1_col1,#T_8a599_row1_col2,#T_8a599_row1_col3,#T_8a599_row1_col4,#T_8a599_row1_col5,#T_8a599_row1_col6,#T_8a599_row1_col7,#T_8a599_row1_col8,#T_8a599_row1_col9,#T_8a599_row1_col10,#T_8a599_row1_col11,#T_8a599_row2_col0,#T_8a599_row2_col1,#T_8a599_row2_col2,#T_8a599_row2_col3,#T_8a599_row2_col4,#T_8a599_row2_col5,#T_8a599_row2_col6,#T_8a599_row2_col7,#T_8a599_row2_col8,#T_8a599_row2_col9,#T_8a599_row2_col10,#T_8a599_row2_col11{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_8a599_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >ProgramID</th>        <th class="col_heading level0 col2" >ProgramName_0</th>        <th class="col_heading level0 col3" >ProgramVersion_1</th>        <th class="col_heading level0 col4" >VendorName_2</th>        <th class="col_heading level0 col5" >InstallDateEpoch_b</th>        <th class="col_heading level0 col6" >InstallSource_6</th>        <th class="col_heading level0 col7" >UninstallRegistryKey_7</th>        <th class="col_heading level0 col8" >PathsList_d</th>        <th class="col_heading level0 col9" >UnknownGuid_10</th>        <th class="col_heading level0 col10" >UnknownGuid_12</th>        <th class="col_heading level0 col11" >UnknownDword_18</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8a599_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8a599_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_8a599_row0_col1" class="data row0 col1" >0000a636d5d4fb40a944b3f5294471cb4bb90000ffff</td>
#                         <td id="T_8a599_row0_col2" class="data row0 col2" >Microsoft Visual C++ 2015-2019 Redistributable (x86) - 14.20.27508</td>
#                         <td id="T_8a599_row0_col3" class="data row0 col3" >14.20.27508.1</td>
#                         <td id="T_8a599_row0_col4" class="data row0 col4" >Microsoft Corporation</td>
#                         <td id="T_8a599_row0_col5" class="data row0 col5" ><NA></td>
#                         <td id="T_8a599_row0_col6" class="data row0 col6" >HKEY_LOCAL_MACHINE\Software\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\{8c3f057e-d6a6-4338-ac6a-f1c795a6577b}</td>
#                         <td id="T_8a599_row0_col7" class="data row0 col7" >c:\programdata\package cache\{8c3f057e-d6a6-4338-ac6a-f1c795a6577b}</td>
#                         <td id="T_8a599_row0_col8" class="data row0 col8" ><NA></td>
#                         <td id="T_8a599_row0_col9" class="data row0 col9" ><NA></td>
#                         <td id="T_8a599_row0_col10" class="data row0 col10" ><NA></td>
#                         <td id="T_8a599_row0_col11" class="data row0 col11" ><NA></td>
#             </tr>
#             <tr>
#                         <th id="T_8a599_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8a599_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_8a599_row1_col1" class="data row1 col1" >0000e2ce9887c6c3734778b91e2495348be900000904</td>
#                         <td id="T_8a599_row1_col2" class="data row1 col2" >VMware Tools</td>
#                         <td id="T_8a599_row1_col3" class="data row1 col3" >11.0.6.15940789</td>
#                         <td id="T_8a599_row1_col4" class="data row1 col4" >VMware, Inc.</td>
#                         <td id="T_8a599_row1_col5" class="data row1 col5" >1033</td>
#                         <td id="T_8a599_row1_col6" class="data row1 col6" >HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\CurrentVersion\Uninstall\{D533345C-7F8D-4807-AE80-E06CE2045B0E}</td>
#                         <td id="T_8a599_row1_col7" class="data row1 col7" >c:\program files\vmware\vmware tools c:\program files\vmware\vmware tools\vmware vgauth c:\program files\vmware\vmware tools\plugins c:\program files\vmware\vmware tools\plugins\common c:\program files\vmware\vmware tools\plugins\vmsvc c:\program files\vmware\vmware tools\plugins\vmusr c:\program files\vmware\vmware tools\win32 c:\program files\vmware\vmware tools\win64</td>
#                         <td id="T_8a599_row1_col8" class="data row1 col8" >{E398C5BD-CB4E-4AD5-B0E6-EEA32C16AA23}</td>
#                         <td id="T_8a599_row1_col9" class="data row1 col9" >{E398C5BD-CB4E-4AD5-B0E6-EEA32C16AA23}</td>
#                         <td id="T_8a599_row1_col10" class="data row1 col10" >{d533345c-7f8d-4807-ae80-e06ce2045b0e}</td>
#                         <td id="T_8a599_row1_col11" class="data row1 col11" >{d533345c-7f8d-4807-ae80-e06ce2045b0e}</td>
#             </tr>
#             <tr>
#                         <th id="T_8a599_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8a599_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_8a599_row2_col1" class="data row2 col1" >0000ef5c753af38a89bc2e5a8b2f982d5c510000ffff</td>
#                         <td id="T_8a599_row2_col2" class="data row2 col2" >Microsoft Visual C++ 2015-2019 Redistributable (x64) - 14.20.27508</td>
#                         <td id="T_8a599_row2_col3" class="data row2 col3" >14.20.27508.1</td>
#                         <td id="T_8a599_row2_col4" class="data row2 col4" >Microsoft Corporation</td>
#                         <td id="T_8a599_row2_col5" class="data row2 col5" ><NA></td>
#                         <td id="T_8a599_row2_col6" class="data row2 col6" >HKEY_LOCAL_MACHINE\Software\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\{7b178cda-9740-4701-a92a-f168d213b343}</td>
#                         <td id="T_8a599_row2_col7" class="data row2 col7" >c:\programdata\package cache\{7b178cda-9740-4701-a92a-f168d213b343}</td>
#                         <td id="T_8a599_row2_col8" class="data row2 col8" ><NA></td>
#                         <td id="T_8a599_row2_col9" class="data row2 col9" ><NA></td>
#                         <td id="T_8a599_row2_col10" class="data row2 col10" ><NA></td>
#                         <td id="T_8a599_row2_col11" class="data row2 col11" ><NA></td>
#             </tr>
#     </tbody></table>
# -------------------------------------------------------------------------------------------------------------
# output/csv/ProgramExecution-Amcache_UnassociatedFileEntries
# **Statistics:**
# <br>No. Entries: 2
# **Constant Columns**
#    Column              \
# 0        D4_DataType_
# 1    D4_Orchestrator_
# 2            D4_Tool_
# 3          D4_Plugin_
# 4        D4_Hostname_
# ..                ...
# 25           LinkDate
# 26         LanguageID
# 27        ProductName
# 28        CompanyName
# 29  SwitchBackContext
#
#    Value
# 0                                                           nan
# 1                                                          kape
# 2                                                          kape
# 3   output/csv/ProgramExecution-Amcache_UnassociatedFileEntries
# 4                                   20200918_0347_cdrive-ft-p03
# ..                                                          ...
# 25                                                         <NA>
# 26                                                         <NA>
# 27                                                         <NA>
# 28                                                         <NA>
# 29                                                         <NA>
#
# [30 rows x 2 columns]
# <style  type="text/css" >
# #T_58599_row0_col0,#T_58599_row0_col1,#T_58599_row0_col2,#T_58599_row0_col3,#T_58599_row0_col4,#T_58599_row0_col5,#T_58599_row0_col6,#T_58599_row0_col7,#T_58599_row1_col0,#T_58599_row1_col1,#T_58599_row1_col2,#T_58599_row1_col3,#T_58599_row1_col4,#T_58599_row1_col5,#T_58599_row1_col6,#T_58599_row1_col7{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_58599_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >ProgramID</th>        <th class="col_heading level0 col2" >FileID</th>        <th class="col_heading level0 col3" >SHA1</th>        <th class="col_heading level0 col4" >FullPath</th>        <th class="col_heading level0 col5" >MFTEntryNumber</th>        <th class="col_heading level0 col6" >MFTSequenceNumber</th>        <th class="col_heading level0 col7" >LastModifiedStore</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58599_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_58599_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_58599_row0_col1" class="data row0 col1" >0003642c38f85d3a219c61e891ddbc809d9a0000ffff</td>
#                         <td id="T_58599_row0_col2" class="data row0 col2" >100001514e</td>
#                         <td id="T_58599_row0_col3" class="data row0 col3" >0d564796c79e87ccb49af7b8b0a9369363ff2c8c</td>
#                         <td id="T_58599_row0_col4" class="data row0 col4" >C:\Program Files\Common Files\VMware\Drivers\vss\comreg.exe</td>
#                         <td id="T_58599_row0_col5" class="data row0 col5" >86350</td>
#                         <td id="T_58599_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_58599_row0_col7" class="data row0 col7" >2020-03-30 22:49:38</td>
#             </tr>
#             <tr>
#                         <th id="T_58599_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_58599_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_58599_row1_col1" class="data row1 col1" >0003c718d3349af13e75429d9874da2522f70000ffff</td>
#                         <td id="T_58599_row1_col2" class="data row1 col2" >20000152bf</td>
#                         <td id="T_58599_row1_col3" class="data row1 col3" >f0032dfb7e5d67dd10568e61787a4a3032ff55f5</td>
#                         <td id="T_58599_row1_col4" class="data row1 col4" >C:\Windows\System32\vm3dservice.exe</td>
#                         <td id="T_58599_row1_col5" class="data row1 col5" >86719</td>
#                         <td id="T_58599_row1_col6" class="data row1 col6" >2</td>
#                         <td id="T_58599_row1_col7" class="data row1 col7" >2020-03-30 22:49:51</td>
#             </tr>
#     </tbody></table>
# -------------------------------------------------------------------------------------------------------------
# output/csv/ProgramExecution-Windows81_Windows2012R2_SYSTEM_AppCompatCache
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 280
# **Constant Columns**
#   Column             \
# 0      D4_DataType_
# 1  D4_Orchestrator_
# 2          D4_Tool_
# 3        D4_Plugin_
# 4      D4_Hostname_
#
#   Value
# 0                                                                        nan
# 1                                                                       kape
# 2                                                                       kape
# 3  output/csv/ProgramExecution-Windows81_Windows2012R2_SYSTEM_AppCompatCache
# 4                                                20200918_0347_cdrive-ft-p03
#      ControlSet  CacheEntryPosition  \
# 0    1             0
# 1    1             1
# 2    1             2
# 3    1             3
# 4    1             4
# ..          ...                 ...
# 275  2           135
# 276  2           136
# 277  2           137
# 278  2           138
# 279  2           139
#
#     Path                                                    \
# 0                      SYSVOL\Windows\System32\LogonUI.exe
# 1    SYSVOL\Program Files\VMware\VMware Tools\vmtoolsd.exe
# 2                  SYSVOL\Windows\System32\vm3dservice.exe
# 3                SYSVOL\Windows\System32\wbem\WmiPrvSE.exe
# 4                SYSVOL\Windows\System32\ServerManager.exe
# ..                                                     ...
# 275                   SYSVOL\Windows\SysWOW64\explorer.exe
# 276                     SYSVOL\Windows\SysWOW64\dpnsvr.exe
# 277                   SYSVOL\Windows\SysWOW64\dplaysvr.exe
# 278                   SYSVOL\Windows\System32\regsvr32.exe
# 279                     SYSVOL\Windows\System32\dpnsvr.exe
#
# ...
#                         <td id="T_dfcd6_row0_col9" class="data row0 col9" >2020-09-19 03:35:08</td>
#             </tr>
#             <tr>
#                         <th id="T_dfcd6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dfcd6_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_dfcd6_row1_col1" class="data row1 col1" >CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\Explorer\RecentDocs</td>
#                         <td id="T_dfcd6_row1_col2" class="data row1 col2" >5</td>
#                         <td id="T_dfcd6_row1_col3" class="data row1 col3" >RecentDocs</td>
#                         <td id="T_dfcd6_row1_col4" class="data row1 col4" >5</td>
#                         <td id="T_dfcd6_row1_col5" class="data row1 col5" >Beth_Secret.txt</td>
#                         <td id="T_dfcd6_row1_col6" class="data row1 col6" >Beth_Secret.lnk</td>
#                         <td id="T_dfcd6_row1_col7" class="data row1 col7" >1</td>
#                         <td id="T_dfcd6_row1_col8" class="data row1 col8" >NaT</td>
#                         <td id="T_dfcd6_row1_col9" class="data row1 col9" >2020-09-19 03:35:08</td>
#             </tr>
#             <tr>
#                         <th id="T_dfcd6_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dfcd6_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_dfcd6_row2_col1" class="data row2 col1" >CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\Explorer\RecentDocs</td>
#                         <td id="T_dfcd6_row2_col2" class="data row2 col2" >3</td>
#                         <td id="T_dfcd6_row2_col3" class="data row2 col3" >RecentDocs</td>
#                         <td id="T_dfcd6_row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_dfcd6_row2_col5" class="data row2 col5" >Szechuan Sauce.txt</td>
#                         <td id="T_dfcd6_row2_col6" class="data row2 col6" >Szechuan Sauce.lnk</td>
#                         <td id="T_dfcd6_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_dfcd6_row2_col8" class="data row2 col8" >NaT</td>
#                         <td id="T_dfcd6_row2_col9" class="data row2 col9" >NaT</td>
#             </tr>
#             <tr>
#                         <th id="T_dfcd6_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dfcd6_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_dfcd6_row3_col1" class="data row3 col1" >CsiTool-CreateHive-{00000000-0000-0000-0000-00000000
# -------------------------------------------------------------------------------------------------------------
# output/json/Registry-LastVisitedPidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
# **Statistics:**
# <br>No. Entries: 1
# **Constant Columns**
#    Column             \
# 0       D4_DataType_
# 1   D4_Orchestrator_
# 2           D4_Tool_
# 3         D4_Plugin_
# 4       D4_Hostname_
# 5       BatchKeyPath
# 6     BatchValueName
# 7          ValueName
# 8        MruPosition
# 9         Executable
# 10      AbsolutePath
# 11          OpenedOn
# 12           Details
#
#    Value
# 0                                                                                                                                        nan
# 1                                                                                                                                       kape
# 2                                                                                                                                       kape
# 3                                         output/json/Registry-LastVisitedPidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat
# 4                                                                                                                20200918_0347_cdrive-ft-p03
# 5   CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\Explorer\ComDlg32\LastVisitedPidlMRU
# 6                                                                                                                                          0
# 7                                                                                                                                          0
# 8                                                                                                                                          0
# 9                                                                                                                               iexplore.exe
# 10                                                                                                                     My Computer\Downloads
# 11                                                                                                                       2020-09-19 03:24:13
# 12                              Type: Root folder: GUID, Value: My Computer\r\n\r\n\r\nType: Root folder: GUID, Value: Downloads\r\n\r\n\r\n
# <style  type="text/css" >
# </style><table id="T_461fe_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >0</th>    </tr></thead><tbody>
#         </tbody></table>
# -------------------------------------------------------------------------------------------------------------
# output/json/Registry-RECmd_Batch_RECmd_Batch_MC
# WARNING: Too many rows (>20) in DataFrame for beautification. Returning non-beautified output.
#          Specify the "max_rows=" option to increase this value
# **Statistics:**
# <br>No. Entries: 1199
# **Constant Columns**
#   Column            Value
# 0      D4_DataType_                                              nan
# 1  D4_Orchestrator_                                             kape
# 2          D4_Tool_                                             kape
# 3        D4_Plugin_  output/json/Registry-RECmd_Batch_RECmd_Batch_MC
# 4      D4_Hostname_                      20200918_0347_cdrive-ft-p03
# 5           Deleted                                            False
#      HivePath                                                     HiveType  \
# 0     G:\szechuan\kape\artifacts\F\Users\Administrator\ntuser.dat  NtUser
# 1     G:\szechuan\kape\artifacts\F\Users\Administrator\ntuser.dat  NtUser
# 2     G:\szechuan\kape\artifacts\F\Users\Administrator\ntuser.dat  NtUser
# 3     G:\szechuan\kape\artifacts\F\Users\Administrator\ntuser.dat  NtUser
# 4     G:\szechuan\kape\artifacts\F\Users\Administrator\ntuser.dat  NtUser
# ...                                                           ...      ...
# 1194  G:\szechuan\kape\artifacts\F\Windows\system32\config\SYSTEM  System
# 1195  G:\szechuan\kape\artifacts\F\Windows\system32\config\SYSTEM  System
# 1196  G:\szechuan\kape\artifacts\F\Windows\system32\config\SYSTEM  System
# 1197  G:\szechuan\kape\artifacts\F\Windows\system32\config\SYSTEM  System
# 1198  G:\szechuan\kape\artifacts\F\Windows\system32\config\SYSTEM  System
#
#      Description               Category                  \
# 0                   Typed URLs          Browser history
# 1                   Typed URLs          Browser history
# 2       Terminal Server Client   Terminal Server Client
# 3                   CIDSizeMRU  File Access and Opening
# 4           LastVisitedPidlMRU  File Access and Opening
# ...                        ...                      ...
# 1194                     Setup                  Devices
# 1195                     Setup                  Devices
# 1196  Current Control Set Name                  Devices
# 1197             Shutdown Time              System Info
# 1198             Shutdown Time              System Info
#
#      KeyPath                                                                                                                                    \
# 0                                     CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Internet Explorer\TypedURLs
# 1                                     CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Internet Explorer\TypedURLs
# 2                                          CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Terminal Server Client
# 3             CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\Explorer\ComDlg32\CIDSizeMRU
# 4     CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Software\Microsoft\Windows\CurrentVersion\Explorer\ComDlg32\LastVisitedPidlMRU
# ...                                                                                                                                        ...
# 1194                                                                           CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Setup
# 1195                                                                           CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Setup
# 1196                                                                          CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\Select
# 1197                                                   CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\ControlSet001\Control\Windows
# 1198                                                   CsiTool-CreateHive-{00000000-0000-0000-0000-000000000000}\ControlSet002\Control\Windows
#
#      ValueName         ValueType    \
# 0                 url1    (plugin)
# 1                 url2    (plugin)
# 2         UsernameHint    (plugin)
# 3                    0    (plugin)
# 4                    0    (plugin)
# ...                ...         ...
# 1194          CloneTag  RegMultiSz
# 1195  RemoveWindowsOld    RegDword
# 1196           Current    RegDword
# 1197      ShutdownTime   RegBinary
# 1198      ShutdownTime   RegBinary
#
#      ValueData                                                                     \
# 0                                                           http://194.61.24.102/
# 1                                 http://go.microsoft.com/fwlink/p/?LinkId=255141
# 2                                                                 DESKTOP-SDN1RPT
# 3                                                                    iexplore.exe
# 4     Exe: iexplore.exe Folder: iexplore.exe Absolute path: My Computer\Downloads
# ...                                                                           ...
# 1194                                                     Fri Mar 21 12:11:58 2014
# 1195                                                                            0
# 1196                                                                            1
# 1197                                                                (Binary data)
# 1198                                                                (Binary data)
#
#      ValueData2                                \
# 0     Timestamp: 2020-09-19 03:23:41.2809070
# 1                                Timestamp:
# 2            User: C137\Administrator, Mru: 0
# 3        Opened: 2020-09-19 03:24:12.1087877)
# 4        Opened: 2020-09-19 03:24:12.0932532)
# ...                                       ...
# 1194                                     <NA>
# 1195                                     <NA>
# 1196                                     <NA>
# 1197                                     <NA>
# 1198                                     <NA>
#
#      ValueData3                                                                                                         \
# 0                                                                                  Slack: m/fwlink/p/?LinkId=255141 敓癲
# 1                                                                                                              Slack:
# 2                                                                          Last modified: 2020-09-19 03:36:25.5804446
# 3                                                                                                               Mru: 0
# 4     Mru: 0 Details: Type: Root folder: GUID, Value: My Computer
#
#
# Type: Root folder: GUID, Value: Downloads
#
#
#
# ...                                                                                                                ...
# 1194                                                                                                              <NA>
# 1195                                                                                                              <NA>
# 1196                                                                                                              <NA>
# 1197                                                                                                              <NA>
# 1198                                                                                                              <NA>
#
#      Comment                    Recursive LastWriteTimestamp   \
# 0           IE/Edge Typed URLs  False     2020-09-19 03:23:42
# 1           IE/Edge Typed URLs  False     2020-09-19 03:23:42
# 2       Terminal Server Client  False     2020-09-19 03:36:26
# 3                   CIDSizeMRU  False     2020-09-19 03:24:13
# 4           LastVisitedPidlMRU  False     2020-09-19 03:24:13
# ...                        ...        ...                 ...
# 1194                 Setup key  False     2020-09-17 17:59:25
# 1195                 Setup key  False     2020-09-17 17:59:25
# 1196  Current Control Set Name  False     2020-09-17 17:56:14
# 1197             Shutdown Time  False     2020-09-18 23:10:54
# 1198             Shutdown Time  False     2020-09-18 23:10:54
#
#      PluginDetailFile
# 0                G:\szechuan\kape\output\json\Registry\20201116033240_TypedURLs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv
# 1                G:\szechuan\kape\output\json\Registry\20201116033240_TypedURLs_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv
# 2     G:\szechuan\kape\output\json\Registry\20201116033240_TerminalServerClient_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv
# 3               G:\szechuan\kape\output\json\Registry\20201116033240_CIDSizeMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv
# 4       G:\szechuan\kape\output\json\Registry\20201116033240_LastVisitedPidlMRU_G_szechuan_kape_artifacts_F_Users_Administrator_ntuser.dat.csv
# ...                                                                                                                                        ...
# 1194                                                                                                                                      <NA>
# 1195                                                                                                                                      <NA>
# 1196                                                                                                                                      <NA>
# 1197                                                                                                                                      <NA>
# 1198                                                                                                                                      <NA>
#
# [1199 rows x 14 columns]
# -------------------------------------------------------------------------------------------------------------
