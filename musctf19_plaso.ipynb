# %% [markdown]
# **This is just an introduction to the new ds4n6_lib, showing some of the analysis we can perform with just a few instructions. During the next weeks we will be publishing different blog posts explaining new techniques and commands to get more powerful analysis**

# %% [markdown]
# ## **FUNCTIONS, VARS, INIT**

# %% [markdown]
# **We create a couple of variables we will use later: home_path (home path of the created environment) and thisnb (name of the current notebook).**

# %%
home_path=!pwd
thisnb=home_path[0]+"/musctf19_plaso.ipynb"

# %% [markdown]
# ## **IMPORTS & INIT**

# %% [markdown]
# **We load all the needed libraries defined in the imports.ipynb notebook and deactivate the warnings in order to have a clean result.**

# %%
# %run imports.ipynb

# %% [markdown]
# ## **READ DATA**

# %% [markdown]
# **We download the outputs we got from running plaso in the mustctf-19 evidence.**

# %%
url = 'https://drive.google.com/uc?id=1BEOKp92HeC56cRIOfDsbcG2sspamtAJH'
of = 'szechuan_plaso_evtx.json'
gdown.download(url, of, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BEOKp92HeC56cRIOfDsbcG2sspamtAJH
# To: /home/jovyan/szechuan_plaso_evtx.json
# 61.3MB [00:01, 55.8MB/s]
# 'szechuan_plaso_evtx.json'

# %% [markdown]
# **Let's read the plaso outputs with the xread() function from ds4n6_lib. It will generate the .pkl file we will use with the dataframes and store the collection of dataframes in d4.out**

# %%
xread(tool="plaso", rootpath=home_path[0]+"/szechuan_plaso_evtx.json", notebook_file=thisnb)
# Out:
# - Searching notebook for saved input file / folder (_plasod)
#   + Found: /home/jovyan/szechuan_plaso_evtx.json
#
# - Reading file(s):
# - No saved Harmonized pickle file found.
#
#     /home/jovyan/szechuan_plaso_evtx.json
# - Reading json file lines: [0] [50000]
#
# - Generating pandas dataframes:
#   + windows_registry_appcompatcache               ...  [221]
#   + windows_registry_installation                 ...  [1]
#   + windows_registry_userassist                   ...  [16]
#   + windows_lnk_link                              ...  [361]
#   + olecf_item                                    ...  [78]
#   + pe_compilation_compilation_time               ...  [22502]
#   + fs_stat                                       ...  [3047]
#   + windows_registry_key_value                    ...  [23562]
#   + windows_shell_item_file_entry                 ...  [182]
#   + windows_distributed_link_tracking_creation    ...  [12]
#   + msie_webcache_container                       ...  [18]
# - Harmonizing pandas dataframes:
#   + windows_registry_appcompatcache               ...  [OK]
#   + windows_registry_installation                 ...  [OK]
#   + windows_registry_userassist                   ...  [OK]
#   + windows_lnk_link                              ...  [OK]
#   + olecf_item                                    ...  [OK]
#   + pe_compilation_compilation_time               ...  [OK]
#   + fs_stat                                       ...  [OK]
#   + windows_registry_key_value                    ...  [OK]
#   + windows_shell_item_file_entry                 ...  [OK]
#   + windows_distributed_link_tracking_creation    ...  [OK]
#   + msie_webcache_container                       ...  [OK]
# - Done Harmonizing.
#
#
# NOTE: Now you can use the syntax <yourvar>['<datatype>'] to access your specific dataframe
#
# - Reading Done.
#
# - Recover the object read by executing:  myvar = d4.out (e.g. mydf = d4.out)

# %% [markdown]
# **We store the dataframes in a more friendly variable: pldfs.**

# %%
pldfs = d4.out

# %%
# Automatically created - DO NOT EDIT OR REMOVE unless you want to change the file to read (in that case, remove this cell)
# 2021-04-19 08:48:08.632386
# _plasod_f2read = "/home/jovyan/szechuan_plaso_evtx.json"

# %% [markdown]
# **This is an output generated by the framework that is used to let you know the input you are reading.**

# %% [markdown]
# ## **ANALYSIS**

# %% [markdown]
# ### **GENERIC**

# %% [markdown]
# **xdisplay is used to configure the settings of the default dataframe that will be displayed in the next cell.**

# %%
xdisplay()
# Out:
# #### Pandas options
# IntText(value=60, description='display.max_rows: ', style=DescriptionStyle(description_width='initial'))
# IntText(value=10, description='display.min_rows: ', style=DescriptionStyle(description_width='initial'))
# IntText(value=20, description='display.max_columns: ', style=DescriptionStyle(description_width='initial'))
# Dropdown(description='display.colheader_justify: ', options=('right', 'left'), style=DescriptionStyle(descript…
# Checkbox(value=True, description='display.expand_frame_repr', indent=False, style=DescriptionStyle(description…

# %% [markdown]
# **We use the xmenu is to select and display the dataframe we want.**

# %%
xmenu(pldfs)
# Out:
# **DataFrame visualization menu:**
# Box(children=(Dropdown(description='Select DataFrame', layout=Layout(width='550px'), options=('Select DataFram…
# HBox(children=(Label(value='Selected dataframe: '),))
# HBox(children=(HTML(value="<div style='color: orange; font-weight: bold;'>Data Loading. Please Wait…</div>"),)…
# Output(layout=Layout(overflow='auto', width='99%'))
# Output(layout=Layout(overflow='auto', width='99%'))

# %% [markdown]
# **With xanalysis function you can run different predefined analysis. You can use it with a dataframe or a collection (dictionary).**

# %%
xanalysis(pldfs)
# Out:
# **Analisys explorer:**
# Box(children=(Dropdown(description='Analysis object: ', layout=Layout(width='250px'), options=('Select one...'…
# Box(children=(Dropdown(description='Available analysis types: ', layout=Layout(width='550px'), options=(), sty…
# Output(layout=Layout(overflow='auto', width='99%'))

# %% [markdown]
# **This is just an introduction to the new ds4n6_lib, showing some of the analysis we can perform with just a few instructions. During the next weeks we will be publishing different blog posts explaining new techniques and commands to get more powerful analysis**
