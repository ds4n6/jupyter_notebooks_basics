# %% [markdown]
# # **MUSCTF19 - 10 - FSTL - MAIN**

# %% [markdown]
# ## **FUNCTIONS, VARS, INIT**

# %%
# Define your notebook full file path here to be able to automatically store runtime configuration settings in this notebook
thisnb="/mnt/analysis/dev/testing_system/test_notebooks/musctf19__10-fstl-main.ipynb"

# Set casename here. This notebook must be renamed with that name.
# %run /mnt/analysis/dev/testing_system/test_notebooks/musctf19__00_imports_case_variables.ipynb
# Out:
# <style>
# table {float:left}
# </style>

# %% [raw]
# # TO BE COPIED TO OTHER NOTEBOOKS FOR CODE DEBUGGING
#
# importlib.reload(d4fstl)
# # importlib.reload(d4pl)
# importlib.reload(d4com)
# importlib.reload(d4gui)
# importlib.reload(d4evtx)
# importlib.reload(d4mctm)

# %% [markdown]
# ## **READ sleuthkit mactime TIMELINE FILE**

# %% [markdown]
# ### **desktop**

# %%
# Enter computer name here (i.e. evidence file prefix, e.g. compname = "dsk1723")
compname = 'desktop'
hostname = 'desktop'

# %% [markdown]
# #### **PATH DEFINITIONS**

# %% [markdown]
# ##### **FOREST**

# %%
compod  = caseod+'/f4n6/comps/'+compname
plasood = compod+'/filesystem_timeline'

# %% [markdown]
# #### **READ DATA**

# %%
read_data_gui(tool="mactime", rootpath=plasood, notebook_file=thisnb, hostname=hostname, windows=True)
# Out:
# - Searching notebook for saved input file / folder (desktop_mactimed)
#   + Found: /mnt/analysis/cases/magnet_ctf19/f4n6/comps/desktop/filesystem_timeline/desktop.fstl.csv
#
# - Reading file(s):
# - Saved pickle file found:
#       /mnt/analysis/cases/magnet_ctf19/f4n6/comps/desktop/filesystem_timeline/desktop.fstl.csv.ham.pkl
# - Reading data from pickle file.
# - Done.
#
# - Reading Done.
#
# - Recover the object read by executing:  myvar = d4.out (e.g. mydf = d4.out)

# %%
fstldf = d4.out

# %%
# Automatically created - DO NOT EDIT OR REMOVE unless you want to change the file to read (in that case, remove this cell)
# 2021-01-19 08:16:28.622439
# desktop_mactimed_f2read = "/mnt/analysis/cases/magnet_ctf19/f4n6/comps/desktop/filesystem_timeline/desktop.fstl.csv"

# %% [markdown]
# ## **ANALYSIS**

# %% [markdown]
# ### **TESTS**

# %% [markdown]
# ### **GENERIC**

# %%
#fstldfnoham.head(1)

# %%
fstldf.head(1)
# Out:
#   D4_DataType_ D4_Orchestrator_ D4_Tool_ D4_Plugin_ D4_Hostname_  \
# 0  None         None             mactime  None       desktop
#
#   Date                 Size MACB  Mode           UID  GID Meta           \
# 0 1980-01-01 03:00:00  68    m...  -/rrwxrwxrwx  0    0    108712-128-1
#
#   File_Name                                                                                                                                                 \
# 0  C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Users/Administrator/AppData/Local/Google/Chrome/User Data/CertificateTransparency/1043/manifest.json (deleted)
#
#   Type_ PrevType_ Permissions_  Deleted_  Reallocated_ Hostname_ SHA256_Hash_  \
# 0  -     r         rwxrwxrwx    True      False         -         -
#
#   DriveLetter_  VSS_ EVOName_                       EvidenceName_            \
# 0  C            0     mus-ctf-19-desktop-001-ft-p02  mus-ctf-19-desktop-001
#
#    Partition_ Tag_                                      \
# 0  2           C[vss00]{mus-ctf-19-desktop-001-ft-p02}
#
#   FilePath_                                                                                               \
# 0  /Users/Administrator/AppData/Local/Google/Chrome/User Data/CertificateTransparency/1043/manifest.json
#
#    FilePath-Hash_       FSType_ TSNTFSAttr_
# 0  -4728314475359592857  -       STD_INFO

# %%
fstldf.dtypes
# Out:
# D4_DataType_                object
# D4_Orchestrator_            object
# D4_Tool_                    object
# D4_Plugin_                  object
# D4_Hostname_                object
# Date                datetime64[ns]
# Size                         Int64
# MACB                        string
# Mode                        string
# UID                          Int64
# GID                          Int64
# Meta                        string
# File_Name                   string
# Type_                       string
# PrevType_                   string
# Permissions_                string
# Deleted_                   boolean
# Reallocated_               boolean
# Hostname_                   string
# SHA256_Hash_                string
# DriveLetter_                string
# VSS_                         Int64
# EVOName_                    string
# EvidenceName_               string
# Partition_                   Int64
# Tag_                        string
# FilePath_                   string
# FilePath-Hash_               Int64
# FSType_                     string
# TSNTFSAttr_                 string
# dtype: object

# %%
xmenu(fstldf)
# Out:
# **DataFrame visualization menu:**
# Box(children=(Dropdown(description='Select DataFrame or Column', layout=Layout(width='550px'), options=('Selec…
# HBox(children=(Label(value='Selected dataframe: '),))
# HBox(children=(HTML(value="<div style='color: orange; font-weight: bold;'>Data Loading. Please Wait…</div>"),)…
# Output(layout=Layout(overflow='auto', width='99%'))
# Output(layout=Layout(overflow='auto', width='99%'))

# %%
d4.out
# Out:
#        D4_DataType_ D4_Orchestrator_ D4_Tool_ D4_Plugin_ D4_Hostname_  \
# 0       None         None             mactime  None       desktop
# 1       None         None             mactime  None       desktop
# 2       None         None             mactime  None       desktop
# 3       None         None             mactime  None       desktop
# 4       None         None             mactime  None       desktop
# ...             ...              ...      ...        ...          ...
# 837755  None         None             mactime  None       desktop
# 837756  None         None             mactime  None       desktop
# 837757  None         None             mactime  None       desktop
# 837758  None         None             mactime  None       desktop
# 837759  None         None             mactime  None       desktop
#
#        Date                 Size    MACB  Mode           UID  GID  \
# 0      1980-01-01 03:00:00       68  m...  -/rrwxrwxrwx  0    0
# 1      1980-01-01 03:00:00     9495  m...  -/rrwxrwxrwx  0    0
# 2      1980-01-01 03:00:00       76  m...  r/rrwxrwxrwx  0    0
# 3      1980-01-01 03:00:00     1765  m...  r/rrwxrwxrwx  0    0
# 4      1980-01-01 03:00:00       76  m...  r/rrwxrwxrwx  0    0
# ...                    ...      ...   ...           ...  ...  ...
# 837755 2019-03-20 18:02:54  4054016  .a..  r/rrwxrwxrwx  0    0
# 837756 2019-03-20 18:02:54  2253488  .a..  r/rrwxrwxrwx  0    0
# 837757 2019-03-20 18:02:54  2253488  .a..  r/rrwxrwxrwx  0    0
# 837758 2019-03-20 18:02:54  4516352  .a..  r/rrwxrwxrwx  0    0
# 837759 2019-03-20 18:02:54  4516352  .a..  r/rrwxrwxrwx  0    0
#
#        Meta           \
# 0       108712-128-1
# 1       108726-128-4
# 2       108772-128-1
# 3       108775-128-4
# 4       108862-128-1
# ...              ...
# 837755  163303-128-4
# 837756  163439-128-4
# 837757  163439-128-4
# 837758  163567-128-4
# 837759  163567-128-4
#
#        File_Name                                                                                                                                                                    \
# 0                          C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Users/Administrator/AppData/Local/Google/Chrome/User Data/CertificateTransparency/1043/manifest.json (deleted)
# 1       C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Users/Administrator/AppData/Local/Google/Chrome/User Data/CertificateTransparency/1043/_metadata/verified_contents.json (deleted)
# 2                                             C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Users/Administrator/AppData/Local/Google/Chrome/User Data/SSLErrorAssistant/7/manifest.json
# 3                          C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Users/Administrator/AppData/Local/Google/Chrome/User Data/SSLErrorAssistant/7/_metadata/verified_contents.json
# 4                                             C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Users/Administrator/AppData/Local/Google/Chrome/User Data/FileTypePolicies/26/manifest.json
# ...                                                                                                                                                                            ...
# 837755              C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Windows/WinSxS/wow64_microsoft-windows-installer-engine_31bf3856ad364e35_10.0.17134.648_none_ef7c81ad3df57f8f/msi.dll
# 837756                                                                                                      C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Windows/SysWOW64/iertutil.dll
# 837757      C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Windows/WinSxS/wow64_microsoft-windows-ie-runtimeutilities_31bf3856ad364e35_11.0.17134.648_none_775dc1ce406988ba/iertutil.dll
# 837758                                                                                                       C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Windows/SysWOW64/wininet.dll
# 837759    C[vss00]{mus-ctf-19-desktop-001-ft-p02}:/Windows/WinSxS/wow64_microsoft-windows-i..tocolimplementation_31bf3856ad364e35_11.0.17134.648_none_31a30af255b86a5d/wininet.dll
#
#        Type_ PrevType_ Permissions_  Deleted_  Reallocated_ Hostname_  \
# 0       -     r         rwxrwxrwx     True     False         -
# 1       -     r         rwxrwxrwx     True     False         -
# 2       r     r         rwxrwxrwx    False     False         -
# 3       r     r         rwxrwxrwx    False     False         -
# 4       r     r         rwxrwxrwx    False     False         -
# ...      ...       ...          ...       ...           ...       ...
# 837755  r     r         rwxrwxrwx    False     False         -
# 837756  r     r         rwxrwxrwx    False     False         -
# 837757  r     r         rwxrwxrwx    False     False         -
# 837758  r     r         rwxrwxrwx    False     False         -
# 837759  r     r         rwxrwxrwx    False     False         -
#
#        SHA256_Hash_ DriveLetter_  VSS_ EVOName_                        \
# 0       -            C            0     mus-ctf-19-desktop-001-ft-p02
# 1       -            C            0     mus-ctf-19-desktop-001-ft-p02
# 2       -            C            0     mus-ctf-19-desktop-001-ft-p02
# 3       -            C            0     mus-ctf-19-desktop-001-ft-p02
# 4       -            C            0     mus-ctf-19-desktop-001-ft-p02
# ...             ...          ...   ...                            ...
# 837755  -            C            0     mus-ctf-19-desktop-001-ft-p02
# 837756  -            C            0     mus-ctf-19-desktop-001-ft-p02
# 837757  -            C            0     mus-ctf-19-desktop-001-ft-p02
# 837758  -            C            0     mus-ctf-19-desktop-001-ft-p02
# 837759  -            C            0     mus-ctf-19-desktop-001-ft-p02
#
#        EvidenceName_            Partition_  \
# 0       mus-ctf-19-desktop-001  2
# 1       mus-ctf-19-desktop-001  2
# 2       mus-ctf-19-desktop-001  2
# 3       mus-ctf-19-desktop-001  2
# 4       mus-ctf-19-desktop-001  2
# ...                        ...         ...
# 837755  mus-ctf-19-desktop-001  2
# 837756  mus-ctf-19-desktop-001  2
# 837757  mus-ctf-19-desktop-001  2
# 837758  mus-ctf-19-desktop-001  2
# 837759  mus-ctf-19-desktop-001  2
#
#        Tag_                                      \
# 0       C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# 1       C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# 2       C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# 3       C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# 4       C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# ...                                         ...
# 837755  C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# 837756  C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# 837757  C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# 837758  C[vss00]{mus-ctf-19-desktop-001-ft-p02}
# 837759  C[vss00]{mus-ctf-19-desktop-001-ft-p02}
#
#        FilePath_                                                                                                                          \
# 0                                  /Users/Administrator/AppData/Local/Google/Chrome/User Data/CertificateTransparency/1043/manifest.json
# 1               /Users/Administrator/AppData/Local/Google/Chrome/User Data/CertificateTransparency/1043/_metadata/verified_contents.json
# 2                                           /Users/Administrator/AppData/Local/Google/Chrome/User Data/SSLErrorAssistant/7/manifest.json
# 3                        /Users/Administrator/AppData/Local/Google/Chrome/User Data/SSLErrorAssistant/7/_metadata/verified_contents.json
# 4                                           /Users/Administrator/AppData/Local/Google/Chrome/User Data/FileTypePolicies/26/manifest.json
# ...                                                                                                                                  ...
# 837755            /Windows/WinSxS/wow64_microsoft-windows-installer-engine_31bf3856ad364e35_10.0.17134.648_none_ef7c81ad3df57f8f/msi.dll
# 837756                                                                                                    /Windows/SysWOW64/iertutil.dll
# 837757    /Windows/WinSxS/wow64_microsoft-windows-ie-runtimeutilities_31bf3856ad364e35_11.0.17134.648_none_775dc1ce406988ba/iertutil.dll
# 837758                                                                                                     /Windows/SysWOW64/wininet.dll
# 837759  /Windows/WinSxS/wow64_microsoft-windows-i..tocolimplementation_31bf3856ad364e35_11.0.17134.648_none_31a30af255b86a5d/wininet.dll
#
#         FilePath-Hash_       FSType_ TSNTFSAttr_
# 0       -4728314475359592857  -       STD_INFO
# 1        8728897886845745570  -       STD_INFO
# 2       -1741102169832226810  -       STD_INFO
# 3       -3372480689167900422  -       STD_INFO
# 4        2703981220276032940  -       STD_INFO
# ...                      ...     ...         ...
# 837755  -8163746351271113248  -       STD_INFO
# 837756   1827518770663271093  -       STD_INFO
# 837757   6787864563249885954  -       STD_INFO
# 837758   5881211827161530807  -       STD_INFO
# 837759  -8253592544411027797  -       STD_INFO
#
# [837760 rows x 30 columns]

# %%
fstldf.simple()
